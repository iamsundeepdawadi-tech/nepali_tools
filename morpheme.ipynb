# %%
# https://github.com/PraveshKoirala/nepali_morpheme_splitter/blob/master/separate_morphemes.ipynb 
# https://medium.com/@shivagaire/%E0%A4%9B%E0%A4%A8%E0%A5%8D%E0%A4%A6%E0%A4%AE%E0%A4%BE-%E0%A4%95%E0%A4%B5%E0%A4%BF%E0%A4%A4%E0%A4%BE-%E0%A4%95%E0%A4%B8%E0%A4%B0%E0%A5%80-%E0%A4%B2%E0%A5%87%E0%A4%96%E0%A5%8D%E0%A4%A8%E0%A5%87-7782c0a01967

# %%
import re
import pandas as pd
from IPython.display import display

# --- परिभाषाहरू (Definitions) ---
vowel_pattern = r"[\u0905-\u0914]"  # Independent vowels: अ to औ
matra_modifier_pattern = r"[\u093A-\u094C\u0901-\u0903]" # Matras and modifiers
consonant_pattern = r"[क-हज्ञक्ष]" # Consonants including conjuncts
halanta = "्"

# --- सहयोगी Function हरू (Helper Functions) ---
def is_vowel(char):
    return bool(re.match(vowel_pattern, char))

def is_matra_modifier(char):
    return bool(re.match(matra_modifier_pattern, char))

def is_consonant(char):
    return bool(re.match(consonant_pattern, char))

def is_halant(char):
    return char == halanta

def split_syllables(word, split_halanta=False):
    """
    यो function ले नेपाली शब्दलाई त्यसको अक्षर (syllables) मा टुक्राउँछ।

    Args:
        word (str): विभाजन गर्नुपर्ने नेपाली शब्द।
        split_halanta (bool): 
            - False (Default): भाषाको नियमअनुसार सही अक्षरमा विभाजन गर्छ (e.g., 'स्नु' एउटै अक्षर)।
            - True: हल्न्त लागेको हरेक आधा व्यञ्जनलाई छुट्टै टुक्रा मान्छ (e.g., 'स्' र 'नु' छुट्टाछुट्टै)।
    """
    if not re.fullmatch(r"[\u0900-\u097F]+", word):
        print(f"Error: '{word}' मा अमान्य अक्षरहरू छन्।")
        return []

    syllables = []
    current_syllable = ""
    i = 0
    word_len = len(word)

    while i < word_len:
        char = word[i]

        if is_consonant(char):
            current_syllable += char
            
            next_i = i + 1
            if next_i < word_len:
                next_char = word[next_i]
                
                # --- परिमार्जित तर्क (Modified Logic) ---
                if is_halant(next_char):
                    current_syllable += next_char
                    i += 1
                    
                    if split_halanta:
                        # यदि split_halanta=True छ भने, आधा अक्षरलाई छुट्टै टुक्रा बनाउने
                        syllables.append(current_syllable)
                        current_syllable = ""

                elif is_matra_modifier(next_char):
                    current_syllable += next_char
                    i += 1
                    while i + 1 < word_len and is_matra_modifier(word[i + 1]):
                        current_syllable += word[i + 1]
                        i += 1
                    syllables.append(current_syllable)
                    current_syllable = ""
                else:
                    syllables.append(current_syllable)
                    current_syllable = ""
            else:
                syllables.append(current_syllable)
                current_syllable = ""

        elif is_vowel(char):
            if current_syllable:
                syllables.append(current_syllable)
            
            current_syllable = char
            while i + 1 < word_len and is_matra_modifier(word[i + 1]):
                current_syllable += word[i + 1]
                i += 1
            
            syllables.append(current_syllable)
            current_syllable = ""
        
        i += 1

    if current_syllable and syllables and not split_halanta:
        syllables[-1] += current_syllable
    elif current_syllable:
        syllables.append(current_syllable)


    return syllables

# --- Jupyter Notebook मा चलाउने उदाहरण ---

def display_syllables(word):
    """परिणामलाई दुवै तरिकाले देखाउने helper function"""
    print(f"'{word}' शब्दको अक्षर विभाजन:")
    
    # अवस्था १: Default (split_halanta=False) - सही अक्षर विभाजन
    print("\n१. पूर्वनिर्धारित (Default) विभाजन (split_halanta=False):")
    syllables_default = split_syllables(word) # or split_syllables(word, split_halanta=False)
    if syllables_default:
        display(pd.DataFrame(syllables_default, columns=["अक्षर (Syllable)"]))

    # अवस्था २: हल्न्तमा विभाजन (split_halanta=True)
    print("\n२. हल्न्तमा विभाजन (split_halanta=True):")
    syllables_split = split_syllables(word, split_halanta=True)
    if syllables_split:
        display(pd.DataFrame(syllables_split, columns=["टुक्रा (Segment)"]))
        
    print("-" * 40)


# उदाहरण १: 'हाँस्नु'
display_syllables("हाँस्नु")

# उदाहरण २: 'विद्यार्थी'
display_syllables("विद्यार्थी")

# उदाहरण ३: 'संविधान'
display_syllables("श्रीमान")
# Out:
# 'हाँस्नु' शब्दको अक्षर विभाजन:
#
# १. पूर्वनिर्धारित (Default) विभाजन (split_halanta=False):
#   अक्षर (Syllable)
# 0              हाँ
# 1             स्नु
# २. हल्न्तमा विभाजन (split_halanta=True):
#   टुक्रा (Segment)
# 0              हाँ
# 1               स्
# 2               नु
# ----------------------------------------
# 'विद्यार्थी' शब्दको अक्षर विभाजन:
#
# १. पूर्वनिर्धारित (Default) विभाजन (split_halanta=False):
#   अक्षर (Syllable)
# 0               वि
# 1             द्या
# 2             र्थी
# २. हल्न्तमा विभाजन (split_halanta=True):
#   टुक्रा (Segment)
# 0               वि
# 1               द्
# 2               या
# 3               र्
# 4               थी
# ----------------------------------------
# 'श्रीमान' शब्दको अक्षर विभाजन:
#
# १. पूर्वनिर्धारित (Default) विभाजन (split_halanta=False):
#   अक्षर (Syllable)
# 0             श्री
# 1               मा
# 2                न
# २. हल्न्तमा विभाजन (split_halanta=True):
#   टुक्रा (Segment)
# 0               श्
# 1               री
# 2               मा
# 3                न
# ----------------------------------------

# %%
display_syllables("छन्")
# Out:
# 'छन्' शब्दको अक्षर विभाजन:
#
# १. पूर्वनिर्धारित (Default) विभाजन (split_halanta=False):
#   अक्षर (Syllable)
# 0              छन्
# २. हल्न्तमा विभाजन (split_halanta=True):
#   टुक्रा (Segment)
# 0                छ
# 1               न्
# ----------------------------------------

# %%
# All known Chhanda patterns for reference
CHHANDA_PATTERNS = {
    "शार्दूलविक्रीडित": ["SSS IIS ISI IIS SSI SSI S", 19],
    "भुजङ्गप्रयात": ["ISS ISS ISS ISS", 12],
    "तोडक": ["IIS IIS IIS IIS", 12],
    "शिखरिणी": ["ISS SSS III IIS SII I S", 17],
    "मन्दाक्रान्ता": ["SSS SII III SSI SSI S S", 17],
    "वंशस्थ": ["ISI SSI ISI SIS", 12],
    "वसन्ततिलका": ["SSI SII ISI ISI SS", 14],
    "मालिनी": ["III III SSS ISS ISS", 15],
    "स्रग्धरा": ["SSS SIS SII III ISS ISS ISS", 21],
    "जलधरमाला": ["SSSS IIII SSSS", 12],
    "कुसुमविचित्रा": ["III ISS III ISS", 12],
    "अलोला": ["SSS IIS SSS SII S S", 14],
    "विद्युन्माला": ["SSS SSS S S", 8],
    "स्रग्विणी": ["SIS SIS SIS SIS", 12],
    "विद्युल्लेखा": ["S S S S S S", 6],
    "प्रमाणिका": ["ISI SIS I S", 8],
    "चम्पकमाला": ["SII SSS IIS S", 10],
    "इन्द्रवज्रा": ["SSI SSI ISI S S", 11],
    "श्री": ["S", 1],
    "स्वागता": ["SIS III SII S S", 11],
    "रथोद्धता": ["SIS III SIS I S", 11],
    "इन्दिरा": ["III SIS SIS I S", 11],
    "रूपामाली": ["SSS SSS SSS", 9],
    "उपेन्द्रवज्रा": ["ISI SSI ISI S S", 11],
    "शालिनी": ["SSS SSI SSI S S", 11],
    "मालती": ["III ISI ISI SIS", 12],
    "द्रुतविलम्बित": ["III SII SII SIS", 12],
    "मणिमाला": ["SII SSS IIS", 8],
    "पञ्चचामर": ["ISI SIS ISI SIS ISI S", 16],
    "अपराजिता": ["III III SIS IIS I S", 14],
    "प्रीतिमाला": ["SSS ISI SSI ISI SII S", 16],
    "मदिरा": ["SII SII SII SII SII SII SII S", 22],
    "मेघविस्फूर्जिता": ["ISS SSS III IIS SIS SIS S S", 19],
    "प्रहर्षिणी": ["SSS III ISI SIS S", 13],
    "प्रमिताक्षरा": ["IIS ISI IIS IIS", 12],
    "पृथ्वी": ["ISI IIS ISI IIS ISS I S", 17],
    "दुर्मिला": ["IIS IIS IIS IIS IIS IIS IIS IIS", 24],
    "विधाता": ["ISS SIS SSI SSS ISS S", 16],
    "मनिका": ["IIS ISS ISS SIS S", 13],
    "हरिणी": ["III IIS SSS SIS IIS I S", 17],
    "दिक्पाल": ["SSI SIS SSS ISI S S", 14],
    "चित्रपदा": ["SII SII S S", 8],
    "माद्री": ["ISI SSI ISI S", 10],
    "सुप्रतिष्ठा": ["SII S S", 5],
    "तूर्णक": ["SIS ISI SIS ISI SIS", 15],
    "सत्यवती": ["SII SSI SIS S", 11],
    "चित्रिका": ["SIS ISI SIS ISI SIS", 15],
    "इन्द्रवंशा": ["SSI SSI ISI SIS", 12],
    "रुक्मवती": ["SII SSS IIS S", 10],
    "शङ्खनारी": ["ISS ISS", 6],
    "अचलधृति": ["IIIIIIIIIIIIIIII", 16],
    "अनुकुला": ["SII SSI III S S", 11]
}

# %%
import re
import pandas as pd
from collections import Counter



# --- Core Logic: Syllabification and Mātrā Parsing ---

# User's trusted syllabification function
vowel_pattern = r"[\u0905-\u0914]"
matra_modifier_pattern = r"[\u093A-\u094C\u0901-\u0903]"
consonant_pattern = r"[क-हज्ञक्ष]"
halanta = "्"

def is_vowel(char): return bool(re.match(vowel_pattern, char))
def is_matra_modifier(char): return bool(re.match(matra_modifier_pattern, char))
def is_consonant(char): return bool(re.match(consonant_pattern, char))
def is_halant(char): return char == halanta

def split_syllables(word, split_halanta=False):
    word = "".join(word.split())
    if not word: return []
    syllables = []
    current_syllable = ""
    i = 0
    word_len = len(word)
    while i < word_len:
        char = word[i]
        if is_consonant(char):
            current_syllable += char
            next_i = i + 1
            if next_i < word_len:
                next_char = word[next_i]
                if is_halant(next_char):
                    current_syllable += next_char; i += 1
                    if split_halanta: syllables.append(current_syllable); current_syllable = ""
                elif is_matra_modifier(next_char):
                    current_syllable += next_char; i += 1
                    while i + 1 < word_len and is_matra_modifier(word[i + 1]):
                        current_syllable += word[i + 1]; i += 1
                    syllables.append(current_syllable); current_syllable = ""
                else:
                    syllables.append(current_syllable); current_syllable = ""
            else:
                syllables.append(current_syllable); current_syllable = ""
        elif is_vowel(char):
            if current_syllable: syllables.append(current_syllable)
            current_syllable = char
            while i + 1 < word_len and is_matra_modifier(word[i + 1]):
                current_syllable += word[i + 1]; i += 1
            syllables.append(current_syllable); current_syllable = ""
        i += 1
    if current_syllable and syllables and not split_halanta: syllables[-1] += current_syllable
    elif current_syllable: syllables.append(current_syllable)
    return syllables



def parse_matra_pattern(line):
    syllables = split_syllables(line)
    if not syllables: return "", []
    
    matras = []
    num_syllables = len(syllables)
    long_matra_chars = "ाीूेैोौ" + "आईऊएऐओऔ"; modifier_chars = "ंः"
    
    for i, syl in enumerate(syllables):
        is_guru = False
        if i == num_syllables - 1: is_guru = True
        elif any(c in long_matra_chars for c in syl): is_guru = True
        elif any(c in modifier_chars for c in syl): is_guru = True
        elif syl.endswith(halanta): is_guru = True
        elif (i + 1 < num_syllables) and (halanta in syllables[i+1]): is_guru = True
        matras.append('S' if is_guru else 'I')
    print("".join(matras), syllables)
        
    return "".join(matras), syllables

# --- Fuzzy Logic: Levenshtein Distance ---
def levenshtein_distance(s1, s2):
    if len(s1) < len(s2): return levenshtein_distance(s2, s1)
    if len(s2) == 0: return len(s1)
    previous_row = range(len(s2) + 1)
    for i, c1 in enumerate(s1):
        current_row = [i + 1]
        for j, c2 in enumerate(s2):
            insertions = previous_row[j + 1] + 1
            deletions = current_row[j] + 1
            substitutions = previous_row[j] + (c1 != c2)
            current_row.append(min(insertions, deletions, substitutions))
        previous_row = current_row
    return previous_row[-1]

# --- Main Analysis Engine ---
def analyze_poem(poem_text):
    lines = [line.strip() for line in poem_text.strip().split('\n') if line.strip()]
    if not lines:
        print("Poem is empty.")
        return

    # 1. Suggest possibilities based on first line's syllable count
    first_line_pattern, first_line_syllables = parse_matra_pattern(lines[0])
    syllable_count = len(first_line_syllables)
    possible_chhandas = [name for name, (_, length) in CHHANDA_PATTERNS.items() if length == syllable_count]

    print(f"विश्लेषण: '{lines[0]}...'")
    print("-" * 30)
    print(f" syllable count ({syllable_count}) Chhandas: {', '.join(possible_chhandas) or 'None'}")
    
    line_results = []
    overall_matches = []

    # 2. Analyze each line for exact and fuzzy matches
    for i, line in enumerate(lines):
        line_pattern, syllables = parse_matra_pattern(line)
        if not line_pattern: continue

        exact_match = "None"
        for name, (pattern, length) in CHHANDA_PATTERNS.items():
            if len(syllables) == length and pattern.replace(" ", "") == line_pattern:
                exact_match = name
                overall_matches.append(name)
                break
        
        # Fuzzy match if no exact match found
        closest_match = "None"
        if exact_match == "None":
            min_dist = float('inf')
            for name, (pattern, length) in CHHANDA_PATTERNS.items():
                if len(syllables) == length:
                    dist = levenshtein_distance(line_pattern, pattern.replace(" ", ""))
                    if dist < min_dist:
                        min_dist = dist
                        closest_match = f"{name} (diff: {dist})"
            overall_matches.append(closest_match.split(" (")[0])


        line_results.append(f"Line {i+1}: Pattern={line_pattern}, Exact Match='{exact_match}', Closest Match='{closest_match}'")

    print("\nDetailed Line-by-Line Analysis:")
    for res in line_results:
        print(res)

    # 3. Conclude the most suitable Chhanda
    if overall_matches:
        most_common = Counter(overall_matches).most_common(1)[0][0]
        print(f"\nMost Suitable Chhanda: {most_common}")
    else:
        print("\nCould not determine a suitable Chhanda.")
    print("=" * 40 + "\n")

# %%
CHHANDA_EXAMPLES = {
  "शार्दूलविक्रीडित": {
    "chhanda": "शार्दूलविक्रीडित",
    "lines": "कन्यादान भयाे थिए दुईजना भाेका भगत् धर्मका\nपानीदार विहा गरेर अँजुली जाेडी दिए कर्मका"
  },
  "भुजङ्गप्रयात": {
    "chhanda": "भुजङ्गप्रयात",
    "lines": "दिई दर्द झन् सर्प डस्दैछ ऐले\nछिमेकी बिना शर्म पस्दैछ ऐले"
  },
  "अनुष्टुप": {
    "chhanda": "अनुष्टुप",
    "lines": "देश छैन पिता छैन माता छैन न मित्र छन्\nन बधु छन् न स्वास्नी छन् न कतै घरवार छन्"
  },
  "मन्दाक्रान्ता": {
    "chhanda": "मन्दाक्रान्ता",
    "lines": "छाना लाए घर हुन गयाे जिन्दगी छैन भित्र\nमुर्दा मुर्दा दुई दिल विहा गर्दछन् याे विचित्र"
  },
  "जलधरमाला": {
    "chhanda": "जलधरमाला",
    "lines": "बाबा आमा हितकर बोली भन्छन्\nसाना नानी अहित भनेझैं ठान्छन्"
  },
  "कुसुमविचित्रा": {
    "chhanda": "कुसुमविचित्रा",
    "lines": "बुझ न मधेसी मुलुक नभाँड\nरिपुसँग मिल्दै ह्रदय नफाँड"
  },
  "शिखरिणी": {
    "chhanda": "शिखरिणी",
    "lines": "छ धर्तीमा शोभा अनुपम कतै प्रस्ट छ तर\nकतै लुक्छन् भित्रै प्रकटित नभै चित्र लहर ।"
  },
  "अलोला": {
    "chhanda": "अलोला",
    "lines": "तारा सुन्दर चम्कून् धर्ती उज्ज्वल होऊन् ।\nनेपाली मन मैलो वर्षाले सरि धोऊन् ।।"
  },
  "विद्युन्माला": {
    "chhanda": "विद्युन्माला",
    "lines": "छारो हानी तर्साएर\nकालो छाया बर्साएर"
  },
  "स्रग्विणी": {
    "chhanda": "स्रग्विणी",
    "lines": "दौडिए जिन्दगी साँझमा रातमा\nनित्यको खोजमा दालमा भातमा।"
  },
  "उपजाति": {
    "chhanda": "उपजाति",
    "lines": "टुटेर नै बादल झार्छ पानी\nफुटेर नै पत्थर बन्छ खानी"
  },
  "विद्युल्लेखा": {
    "chhanda": "विद्युल्लेखा",
    "lines": "छैनन् मान्छेवादी\nकोही माओवादी"
  },
  "प्रमाणिका": {
    "chhanda": "प्रमाणिका",
    "lines": "म माझ प्रेमको चरो\nकराउँदैछ सुस्तरी"
  },
  "चम्पकमाला": {
    "chhanda": "चम्पकमाला",
    "lines": "शङ्कर बाबा शङ्कर बाबा\nदुःख निकै भो शङ्कर बाबा"
  },
  "इन्द्रवज्रा": {
    "chhanda": "इन्द्रवज्रा",
    "lines": "भाषा टिके गौरव टिक्न सक्छ\nपुस्ता नयाँले पनि सिक्न सक्छ ।।"
  },
  "श्री": {
    "chhanda": "श्री",
    "lines": "आ: यो\nके हो ?"
  },
  "स्वागता": {
    "chhanda": "स्वागता",
    "lines": "अङ्ग-भङ्ग हुन गो गरिखाने\nछैन चाहत उसै मरिजाने ।"
  },
  "रथोद्धता": {
    "chhanda": "रथोद्धता",
    "lines": "भो भयो अब यता नफर्कनू\nदुख्छ घाउ जल भै नदर्कनू"
  },
  "वियोगिनी": {
    "chhanda": "वियोगिनी",
    "lines": "तनमा कुन तत्व पो पस्यो ?\nमनमा त्यो किन गै कता बस्यो?"
  },
  "वसन्त मालिका": {
    "chhanda": "वसन्त मालिका",
    "lines": "शवको कुन हुन्छ कामना नै ?\nशवको के छ र भित्र भावना नै ?"
  },
  "इन्दिरा": {
    "chhanda": "इन्दिरा",
    "lines": "अब त माहुरी भुन्भुनाउँदै\nगति बढाउँदै गुन्गुनाउँदै"
  },
  "रूपामाली": {
    "chhanda": "रूपामाली",
    "lines": "हामी माली बालीनालीका\nहामी फाली मेची कालीका"
  },
  "उपेन्द्रवज्रा": {
    "chhanda": "उपेन्द्रवज्रा",
    "lines": "उडेर आकास कहाँ चुमिन्छ\nसुतेर घैटो कसरी भरिन्छ"
  },
  "शालिनी": {
    "chhanda": "शालिनी",
    "lines": "लामो यात्रा पार गर्दै म आए\nसामुन्नेमा भैदिदा लौ रमाए"
  },
  "मालती": {
    "chhanda": "मालती",
    "lines": "नयन कटाक्ष छुरा भनूँ कि के !\nछमछम बज्छ चुरा भनूँ कि के !"
  },
  "द्रुतविलम्वित": {
    "chhanda": "द्रुतविलम्वित",
    "lines": "नयनभित्र नदी छ समुद्र छ।\nतर मुहान उही छ-वि-चित्र छ।।"
  },
  "मणिमाला": {
    "chhanda": "मणिमाला",
    "lines": "खोल्दछ पर्दा त्यो नयमा\nबल्छ सधैं नै जागरमा"
  },
  "पञ्चचामर": {
    "chhanda": "पञ्चचामर",
    "lines": "बसेर देशको सधैँ गरेर हीत खातिर\nमरेर लानु के छ यो अजम्बरी त को छ र"
  },
  "अपराजिता": {
    "chhanda": "अपराजिता",
    "lines": "छल र वल गरी थुनीकन बाँधियो\nडङ कि डङ पिटी अचेत बनाइयो"
  },
  "वसन्ततिलका": {
    "chhanda": "वसन्ततिलका",
    "lines": "रात्री गयो अब प्रभात भएर आयो\nछायो सबैतिर प्रभा सविता उदायो।"
  },
  "प्रीतिमाला": {
    "chhanda": "प्रीतिमाला",
    "lines": "छाती बेस्सरी जलाई,जल नेत्रको सलाई\nफ्याक्दै पासमा नआई,घरबाट दृष्टि लाई"
  },
  "मदिरा": {
    "chhanda": "मदिरा",
    "lines": "ताल बन्यो मदिरा र कुवा पनि भो मदिरा भवसागर भो\nसृष्टि जलामय भो मदिरा तब यो दुनियाँ पनि मातिदियो"
  },
  "मेघविस्फूर्जिता": {
    "chhanda": "मेघविस्फूर्जिता",
    "lines": "लुलाले सिर्जेका अनुपम मिठा, लेख \"हावा\" हुँदै छन्\nबडाले खोकेका, अति विरसिला, शब्द \"वा वा\" हुँदैछन्"
  },
  "वंशस्थ": {
    "chhanda": "वंशस्थ",
    "lines": "पियारको वन्धन पो खडाभयो\nयहाँ तगारो मनको कडा भयो"
  },
  "प्रहर्षिणी": {
    "chhanda": "प्रहर्षिणी",
    "lines": "बच्चाले कतिथरिका मजा लिँदैछन्\nमाटोमा लुटुपुटिँदै रमाउँदैछन् ।।"
  },
  "मात्रिक": {
    "chhanda": "मात्रिक",
    "lines": "म पनि रिले अनसनमा छु\nखाएपछि हाजिर हुन्छु"
  },
  "अार्या": {
    "chhanda": "अार्या",
    "lines": "धन्य छ नारी जीवन, कसले बुझ्न सक्ला र तिम्रो मन\nभित्र वेदना दन्दन , तर पनि बाहिर मुस्कुराउँदै छन् ।।"
  },
  "प्रमिताक्षरा": {
    "chhanda": "प्रमिताक्षरा",
    "lines": "तर यार प्यार नगरी नहुने\nउनको समीप नसरी नहुने"
  },
  "तोडक": {
    "chhanda": "तोडक",
    "lines": "अबता अति भाे,अति नै खति भो।\nसबको मति लौ अति भ्रष्टभयाे।।"
  },
  "पृथ्वी": {
    "chhanda": "पृथ्वी",
    "lines": "अचम्म अति लाग्छ है किन शरीरका अङ्गमा\nविभेद नहुने कठै अधर वा कनिष्ठाङ्गमा ।"
  },
  "दुर्मिला": {
    "chhanda": "दुर्मिला",
    "lines": "जब यो युग नै अलमल्ल भयो, तब यो जग नै खलबल्ल भयो\nरस चुस्छ सधैं भमरो र जुको, अनि फूल सुकी असरल्ल भयो"
  },
  "स्रग्धरा": {
    "chhanda": "स्रग्धरा",
    "lines": "पाखामा खेतमा यी लहलह गहुँका पुष्ट बाली झुलार्इ\nमान्छेको चेतलार्इ प्रकृतिलयसँगै दूर तान्दै डुलार्इ ।"
  },
  "विधाता": {
    "chhanda": "विधाता",
    "lines": "उनी रानी म ता राजा बनेको त्यो कुरा आयो\nसगै बाचौ मरौ हामी भनेको त्यो कुरा आयो ।"
  },
  "मनिका": {
    "chhanda": "मनिका",
    "lines": "गणतन्त्र आयो अरू, के पो पुगेन?\nर शहीद,का रक्तका, टाटा सुकेन।।"
  },
  "हरिणी": {
    "chhanda": "हरिणी",
    "lines": "कुसुमदल ! फक्रेको उद्यानमा किन हो भन ?\nभ्रमरकुल झुल्दै छन् माधुर्यको कविता लिन"
  },
  "दिक्पाल": {
    "chhanda": "दिक्पाल",
    "lines": "थामेर हात तिम्रो,बाँचे म आज सम्म\nपाएर साथ तिम्रो,बाँचे म आज सम्म"
  },
  "चित्रपदा": {
    "chhanda": "चित्रपदा",
    "lines": "जान जतातिर जाऊ, यै घरमा मन लाऊ\nदेश रुने नगराऊ, जो सकिने श्रम लाऊ ।।"
  },
  "पुष्पिताग्रा": {
    "chhanda": "पुष्पिताग्रा",
    "lines": "जनन हुन समेत बाबु खोज्ने\nजनन भए उसकै छ वंश बढ्ने"
  },
  "माद्री": {
    "chhanda": "माद्री",
    "lines": "म वेदनामा कसरी बसौँ\nप्रताडनामा कसरी बसौँ"
  },
  "सुप्रतिष्ठा": {
    "chhanda": "सुप्रतिष्ठा",
    "lines": "हेर बिराला\nधूर्त छ चाला"
  },
  "तूर्णक": {
    "chhanda": "तूर्णक",
    "lines": "होस राख, दोष छोड, कर्म गर्न तम्सिद्यौ\nनिष्कलङ्क कर्मबाट बन्छ देश संझिद्यौ।"
  },
  "सत्यवती": {
    "chhanda": "सत्यवती",
    "lines": "आखिर छोटो छ जिन्दगानी\nबन्नु छ हामी सबै खरानी"
  },
  "चित्रा": {
    "chhanda": "चित्रा",
    "lines": "द्यौरालीमा पाती मेराे नाम अर्काे परेछ\nसानो छाया प्याराे लाग्थ्यो घाम चर्काे परेछ"
  },
  "चित्रिका": {
    "chhanda": "चित्रिका",
    "lines": "जाग जाग हे युवा उदार शान्त चित्तले\nहाँक्नुपर्छ देश यो सुरम्य नीति वित्तले ।"
  },
  "इन्द्रवंशा": {
    "chhanda": "इन्द्रवंशा",
    "lines": "को हुन् कुदेका किन जालझेलमा\nको हुन् डुबेका किन रक्तभेलमा"
  },
  "रुक्मवती": {
    "chhanda": "रुक्मवती",
    "lines": "भाव विनाको बन्दछ नारा।\nजून फुलाऊ व्योम सितारा।।"
  },
  "चन्द्रलेखा": {
    "chhanda": "चन्द्रलेखा",
    "lines": "आजै एकादशी माछा ता नखाऊँ तुलासी।\nअर्पौं श्री विष्णुमा माला तोरणै फूल गाँसी ।"
  },
  "शङ्खनारी": {
    "chhanda": "शङ्खनारी",
    "lines": "कथा जिन्दगीको\nथिएॅ नेत्रनानी"
  },
  "अचलधृति": {
    "chhanda": "अचलधृति",
    "lines": "अविरल चरण-रज अभिलषित म छु\nद्रवित छ हृदय तर अविचलित म छु"
  },
  "अनुकुला": {
    "chhanda": "अनुकुला",
    "lines": "हेर यहाँ छन् अतिशय पीडा\nखप्दछु जम्मै हरदम हाँसी I"
  },
  "मात्रिक (चौपाइ)": {
    "chhanda": "मात्रिक (चौपाइ)",
    "lines": "सूर्य किरणले तिमिर हरायो\nदुनियाँ उज्ज्वल मधुर गरायो!!"
  },
  "मालिनी": {
    "chhanda": "मालिनी",
    "lines": "कति छ कति गुनासो देश नै भो विरानो\nघर - शहर सबैको आँगनी भो अँध्यारो"
  }
}

# %%
# --- Comprehensive Testing ---
for title, data in CHHANDA_EXAMPLES.items():
    print(f"Testing Poem: {title} (Expected Chhanda: {data['chhanda']})")
    analyze_poem(data['lines'])
# Out:
# Testing Poem: शार्दूलविक्रीडित (Expected Chhanda: शार्दूलविक्रीडित)
# SSSIISISISISSSISSIS ['क', 'न्या', 'दा', 'न', 'भ', 'याे', 'थि', 'ए', 'दु', 'ई', 'ज', 'ना', 'भाे', 'का', 'भ', 'ग', 'त्ध', 'र्म', 'का']
# विश्लेषण: 'कन्यादान भयाे थिए दुईजना भाेका भगत् धर्मका...'
# ------------------------------
#  syllable count (19) Chhandas: शार्दूलविक्रीडित, मेघविस्फूर्जिता
# SSSIISISISISSSISSIS ['क', 'न्या', 'दा', 'न', 'भ', 'याे', 'थि', 'ए', 'दु', 'ई', 'ज', 'ना', 'भाे', 'का', 'भ', 'ग', 'त्ध', 'र्म', 'का']
# SSSIISISIIISSSISSIS ['पा', 'नी', 'दा', 'र', 'वि', 'हा', 'ग', 'रे', 'र', 'अँ', 'जु', 'ली', 'जाे', 'डी', 'दि', 'ए', 'क', 'र्म', 'का']
#
# Detailed Line-by-Line Analysis:
# Line 1: Pattern=SSSIISISISISSSISSIS, Exact Match='None', Closest Match='शार्दूलविक्रीडित (diff: 1)'
# Line 2: Pattern=SSSIISISIIISSSISSIS, Exact Match='शार्दूलविक्रीडित', Closest Match='None'
#
# Most Suitable Chhanda: शार्दूलविक्रीडित
# ========================================
#
# Testing Poem: भुजङ्गप्रयात (Expected Chhanda: भुजङ्गप्रयात)
# ISSISSISSISS ['दि', 'ई', 'द', 'र्द', 'झ', 'न्स', 'र्प', 'ड', 'स्दै', 'छ', 'ऐ', 'ले']
# विश्लेषण: 'दिई दर्द झन् सर्प डस्दैछ ऐले...'
# ------------------------------
#  syllable count (12) Chhandas: भुजङ्गप्रयात, तोडक, वंशस्थ, जलधरमाला, कुसुमविचित्रा, स्रग्विणी, मालती, द्रुतविलम्बित, प्रमिताक्षरा, इन्द्रवंशा
# ISSISSISSISS ['दि', 'ई', 'द', 'र्द', 'झ', 'न्स', 'र्प', 'ड', 'स्दै', 'छ', 'ऐ', 'ले']
# ISSISSISSISS ['छि', 'मे', 'की', 'बि', 'ना', 'श', 'र्म', 'प', 'स्दै', 'छ', 'ऐ', 'ले']
#
# Detailed Line-by-Line Analysis:
# Line 1: Pattern=ISSISSISSISS, Exact Match='भुजङ्गप्रयात', Closest Match='None'
# Line 2: Pattern=ISSISSISSISS, Exact Match='भुजङ्गप्रयात', Closest Match='None'
#
# Most Suitable Chhanda: भुजङ्गप्रयात
# ========================================
#
# Testing Poem: अनुष्टुप (Expected Chhanda: अनुष्टुप)
# SISIISSISSSIISSS ['दे', 'श', 'छै', 'न', 'पि', 'ता', 'छै', 'न', 'मा', 'ता', 'छै', 'न', 'न', 'मि', 'त्र', 'छन्']
# विश्लेषण: 'देश छैन पिता छैन माता छैन न मित्र छन्...'
# ------------------------------
#  syllable count (16) Chhandas: पञ्चचामर, प्रीतिमाला, विधाता, अचलधृति
# SISIISSISSSIISSS ['दे', 'श', 'छै', 'न', 'पि', 'ता', 'छै', 'न', 'मा', 'ता', 'छै', 'न', 'न', 'मि', 'त्र', 'छन्']
# IIISSSSSIISIISSS ['न', 'ब', 'धु', 'छ', 'न्न', 'स्वा', 'स्नी', 'छ', 'न्न', 'क', 'तै', 'घ', 'र', 'वा', 'र', 'छन्']
#
# Detailed Line-by-Line Analysis:
# Line 1: Pattern=SISIISSISSSIISSS, Exact Match='None', Closest Match='विधाता (diff: 4)'
# Line 2: Pattern=IIISSSSSIISIISSS, Exact Match='None', Closest Match='विधाता (diff: 5)'
#
# Most Suitable Chhanda: विधाता
# ========================================
#
# Testing Poem: मन्दाक्रान्ता (Expected Chhanda: मन्दाक्रान्ता)
# SSSSIIIIISSISSISS ['छा', 'ना', 'ला', 'ए', 'घ', 'र', 'हु', 'न', 'ग', 'याे', 'जि', 'न्द', 'गी', 'छै', 'न', 'भि', 'त्र']
# विश्लेषण: 'छाना लाए घर हुन गयाे जिन्दगी छैन भित्र...'
# ------------------------------
#  syllable count (17) Chhandas: शिखरिणी, मन्दाक्रान्ता, पृथ्वी, हरिणी
# SSSSIIIIISSISSISS ['छा', 'ना', 'ला', 'ए', 'घ', 'र', 'हु', 'न', 'ग', 'याे', 'जि', 'न्द', 'गी', 'छै', 'न', 'भि', 'त्र']
# SSSSISIIISSISSISS ['मु', 'र्दा', 'मु', 'र्दा', 'दु', 'ई', 'दि', 'ल', 'वि', 'हा', 'ग', 'र्द', 'छ', 'न्याे', 'वि', 'चि', 'त्र']
#
# Detailed Line-by-Line Analysis:
# Line 1: Pattern=SSSSIIIIISSISSISS, Exact Match='मन्दाक्रान्ता', Closest Match='None'
# Line 2: Pattern=SSSSISIIISSISSISS, Exact Match='None', Closest Match='मन्दाक्रान्ता (diff: 1)'
#
# Most Suitable Chhanda: मन्दाक्रान्ता
# ========================================
#
# Testing Poem: जलधरमाला (Expected Chhanda: जलधरमाला)
# SSSSIIIISSSS ['बा', 'बा', 'आ', 'मा', 'हि', 'त', 'क', 'र', 'बो', 'ली', 'भ', 'न्छन्']
# विश्लेषण: 'बाबा आमा हितकर बोली भन्छन्...'
# ------------------------------
#  syllable count (12) Chhandas: भुजङ्गप्रयात, तोडक, वंशस्थ, जलधरमाला, कुसुमविचित्रा, स्रग्विणी, मालती, द्रुतविलम्बित, प्रमिताक्षरा, इन्द्रवंशा
# SSSSIIIISSSS ['बा', 'बा', 'आ', 'मा', 'हि', 'त', 'क', 'र', 'बो', 'ली', 'भ', 'न्छन्']
# SSSSIIIISSSS ['सा', 'ना', 'ना', 'नी', 'अ', 'हि', 'त', 'भ', 'ने', 'झैं', 'ठा', 'न्छन्']
#
# Detailed Line-by-Line Analysis:
# Line 1: Pattern=SSSSIIIISSSS, Exact Match='जलधरमाला', Closest Match='None'
# Line 2: Pattern=SSSSIIIISSSS, Exact Match='जलधरमाला', Closest Match='None'
#
# Most Suitable Chhanda: जलधरमाला
# ========================================
#
# Testing Poem: कुसुमविचित्रा (Expected Chhanda: कुसुमविचित्रा)
# IIIISSIIIISS ['बु', 'झ', 'न', 'म', 'धे', 'सी', 'मु', 'लु', 'क', 'न', 'भाँ', 'ड']
# विश्लेषण: 'बुझ न मधेसी मुलुक नभाँड...'
# ------------------------------
#  syllable count (12) Chhandas: भुजङ्गप्रयात, तोडक, वंशस्थ, जलधरमाला, कुसुमविचित्रा, स्रग्विणी, मालती, द्रुतविलम्बित, प्रमिताक्षरा, इन्द्रवंशा
# IIIISSIIIISS ['बु', 'झ', 'न', 'म', 'धे', 'सी', 'मु', 'लु', 'क', 'न', 'भाँ', 'ड']
# IIIISSIIIISS ['रि', 'पु', 'सँ', 'ग', 'मि', 'ल्दै', 'ह्र', 'द', 'य', 'न', 'फाँ', 'ड']
#
# Detailed Line-by-Line Analysis:
# Line 1: Pattern=IIIISSIIIISS, Exact Match='कुसुमविचित्रा', Closest Match='None'
# Line 2: Pattern=IIIISSIIIISS, Exact Match='कुसुमविचित्रा', Closest Match='None'
#
# Most Suitable Chhanda: कुसुमविचित्रा
# ========================================
#
# Testing Poem: शिखरिणी (Expected Chhanda: शिखरिणी)
# ISSSSSIIIIISSIIIS ['छ', 'ध', 'र्ती', 'मा', 'शो', 'भा', 'अ', 'नु', 'प', 'म', 'क', 'तै', 'प्र', 'स्ट', 'छ', 'त', 'र']
# विश्लेषण: 'छ धर्तीमा शोभा अनुपम कतै प्रस्ट छ तर...'
# ------------------------------
#  syllable count (17) Chhandas: शिखरिणी, मन्दाक्रान्ता, पृथ्वी, हरिणी
# ISSSSSIIIIISSIIIS ['छ', 'ध', 'र्ती', 'मा', 'शो', 'भा', 'अ', 'नु', 'प', 'म', 'क', 'तै', 'प्र', 'स्ट', 'छ', 'त', 'र']
# ISSSSSIIIIISSIIIS ['क', 'तै', 'लु', 'क्छ', 'न्भि', 'त्रै', 'प्र', 'क', 'टि', 'त', 'न', 'भै', 'चि', 'त्र', 'ल', 'ह', 'र']
#
# Detailed Line-by-Line Analysis:
# Line 1: Pattern=ISSSSSIIIIISSIIIS, Exact Match='शिखरिणी', Closest Match='None'
# Line 2: Pattern=ISSSSSIIIIISSIIIS, Exact Match='शिखरिणी', Closest Match='None'
#
# Most Suitable Chhanda: शिखरिणी
# ========================================
#
# Testing Poem: अलोला (Expected Chhanda: अलोला)
# SSSIISSSSSIISS ['ता', 'रा', 'सु', 'न्द', 'र', 'च', 'म्कू', 'न्ध', 'र्ती', 'उ', 'ज्ज्व', 'ल', 'हो', 'ऊन्']
# विश्लेषण: 'तारा सुन्दर चम्कून् धर्ती उज्ज्वल होऊन् ।...'
# ------------------------------
#  syllable count (14) Chhandas: वसन्ततिलका, अलोला, अपराजिता, दिक्पाल
# SSSIISSSSSIISS ['ता', 'रा', 'सु', 'न्द', 'र', 'च', 'म्कू', 'न्ध', 'र्ती', 'उ', 'ज्ज्व', 'ल', 'हो', 'ऊन्']
# SSSIISSSSSIISS ['ने', 'पा', 'ली', 'म', 'न', 'मै', 'लो', 'व', 'र्षा', 'ले', 'स', 'रि', 'धो', 'ऊन्']
#
# Detailed Line-by-Line Analysis:
# Line 1: Pattern=SSSIISSSSSIISS, Exact Match='अलोला', Closest Match='None'
# Line 2: Pattern=SSSIISSSSSIISS, Exact Match='अलोला', Closest Match='None'
#
# Most Suitable Chhanda: अलोला
# ========================================
#
# Testing Poem: विद्युन्माला (Expected Chhanda: विद्युन्माला)
# SSSSSSSS ['छा', 'रो', 'हा', 'नी', 'त', 'र्सा', 'ए', 'र']
# विश्लेषण: 'छारो हानी तर्साएर...'
# ------------------------------
#  syllable count (8) Chhandas: विद्युन्माला, प्रमाणिका, मणिमाला, चित्रपदा
# SSSSSSSS ['छा', 'रो', 'हा', 'नी', 'त', 'र्सा', 'ए', 'र']
# SSSSSSSS ['का', 'लो', 'छा', 'या', 'ब', 'र्सा', 'ए', 'र']
#
# Detailed Line-by-Line Analysis:
# Line 1: Pattern=SSSSSSSS, Exact Match='विद्युन्माला', Closest Match='None'
# Line 2: Pattern=SSSSSSSS, Exact Match='विद्युन्माला', Closest Match='None'
#
# Most Suitable Chhanda: विद्युन्माला
# ========================================
#
# Testing Poem: स्रग्विणी (Expected Chhanda: स्रग्विणी)
# SISSISSISSIS ['दौ', 'डि', 'ए', 'जि', 'न्द', 'गी', 'साँ', 'झ', 'मा', 'रा', 'त', 'मा']
# विश्लेषण: 'दौडिए जिन्दगी साँझमा रातमा...'
# ------------------------------
#  syllable count (12) Chhandas: भुजङ्गप्रयात, तोडक, वंशस्थ, जलधरमाला, कुसुमविचित्रा, स्रग्विणी, मालती, द्रुतविलम्बित, प्रमिताक्षरा, इन्द्रवंशा
# SISSISSISSIS ['दौ', 'डि', 'ए', 'जि', 'न्द', 'गी', 'साँ', 'झ', 'मा', 'रा', 'त', 'मा']
# SISSISSISSIS ['नि', 'त्य', 'को', 'खो', 'ज', 'मा', 'दा', 'ल', 'मा', 'भा', 'त', 'मा']
#
# Detailed Line-by-Line Analysis:
# Line 1: Pattern=SISSISSISSIS, Exact Match='स्रग्विणी', Closest Match='None'
# Line 2: Pattern=SISSISSISSIS, Exact Match='स्रग्विणी', Closest Match='None'
#
# Most Suitable Chhanda: स्रग्विणी
# ========================================
#
# Testing Poem: उपजाति (Expected Chhanda: उपजाति)
# ISISSIISISS ['टु', 'टे', 'र', 'नै', 'बा', 'द', 'ल', 'झा', 'र्छ', 'पा', 'नी']
# विश्लेषण: 'टुटेर नै बादल झार्छ पानी...'
# ------------------------------
#  syllable count (11) Chhandas: इन्द्रवज्रा, स्वागता, रथोद्धता, इन्दिरा, उपेन्द्रवज्रा, शालिनी, सत्यवती, अनुकुला
# ISISSIISISS ['टु', 'टे', 'र', 'नै', 'बा', 'द', 'ल', 'झा', 'र्छ', 'पा', 'नी']
# ISISSIISISS ['फु', 'टे', 'र', 'नै', 'प', 'त्थ', 'र', 'ब', 'न्छ', 'खा', 'नी']
#
# Detailed Line-by-Line Analysis:
# Line 1: Pattern=ISISSIISISS, Exact Match='उपेन्द्रवज्रा', Closest Match='None'
# Line 2: Pattern=ISISSIISISS, Exact Match='उपेन्द्रवज्रा', Closest Match='None'
#
# Most Suitable Chhanda: उपेन्द्रवज्रा
# ========================================
#
# Testing Poem: विद्युल्लेखा (Expected Chhanda: विद्युल्लेखा)
# SSSSSS ['छै', 'न', 'न्मा', 'न्छे', 'वा', 'दी']
# विश्लेषण: 'छैनन् मान्छेवादी...'
# ------------------------------
#  syllable count (6) Chhandas: विद्युल्लेखा, शङ्खनारी
# SSSSSS ['छै', 'न', 'न्मा', 'न्छे', 'वा', 'दी']
# SSSSSS ['को', 'ही', 'मा', 'ओ', 'वा', 'दी']
#
# Detailed Line-by-Line Analysis:
# Line 1: Pattern=SSSSSS, Exact Match='विद्युल्लेखा', Closest Match='None'
# Line 2: Pattern=SSSSSS, Exact Match='विद्युल्लेखा', Closest Match='None'
#
# Most Suitable Chhanda: विद्युल्लेखा
# ========================================
#
# Testing Poem: प्रमाणिका (Expected Chhanda: प्रमाणिका)
# ISSSISIS ['म', 'मा', 'झ', 'प्रे', 'म', 'को', 'च', 'रो']
# विश्लेषण: 'म माझ प्रेमको चरो...'
# ------------------------------
#  syllable count (8) Chhandas: विद्युन्माला, प्रमाणिका, मणिमाला, चित्रपदा
# ISSSISIS ['म', 'मा', 'झ', 'प्रे', 'म', 'को', 'च', 'रो']
# ISISISIS ['क', 'रा', 'उँ', 'दै', 'छ', 'सु', 'स्त', 'री']
#
# Detailed Line-by-Line Analysis:
# Line 1: Pattern=ISSSISIS, Exact Match='None', Closest Match='प्रमाणिका (diff: 1)'
# Line 2: Pattern=ISISISIS, Exact Match='प्रमाणिका', Closest Match='None'
#
# Most Suitable Chhanda: प्रमाणिका
# ========================================
#
# Testing Poem: चम्पकमाला (Expected Chhanda: चम्पकमाला)
# SIISSSIISS ['श', 'ङ्क', 'र', 'बा', 'बा', 'श', 'ङ्क', 'र', 'बा', 'बा']
# विश्लेषण: 'शङ्कर बाबा शङ्कर बाबा...'
# ------------------------------
#  syllable count (10) Chhandas: चम्पकमाला, माद्री, रुक्मवती
# SIISSSIISS ['श', 'ङ्क', 'र', 'बा', 'बा', 'श', 'ङ्क', 'र', 'बा', 'बा']
# SIISSSIISS ['दुः', 'ख', 'नि', 'कै', 'भो', 'श', 'ङ्क', 'र', 'बा', 'बा']
#
# Detailed Line-by-Line Analysis:
# Line 1: Pattern=SIISSSIISS, Exact Match='चम्पकमाला', Closest Match='None'
# Line 2: Pattern=SIISSSIISS, Exact Match='चम्पकमाला', Closest Match='None'
#
# Most Suitable Chhanda: चम्पकमाला
# ========================================
#
# Testing Poem: इन्द्रवज्रा (Expected Chhanda: इन्द्रवज्रा)
# SSISSIISISS ['भा', 'षा', 'टि', 'के', 'गौ', 'र', 'व', 'टि', 'क्न', 'स', 'क्छ']
# विश्लेषण: 'भाषा टिके गौरव टिक्न सक्छ...'
# ------------------------------
#  syllable count (11) Chhandas: इन्द्रवज्रा, स्वागता, रथोद्धता, इन्दिरा, उपेन्द्रवज्रा, शालिनी, सत्यवती, अनुकुला
# SSISSIISISS ['भा', 'षा', 'टि', 'के', 'गौ', 'र', 'व', 'टि', 'क्न', 'स', 'क्छ']
# SSISSIISISS ['पु', 'स्ता', 'न', 'याँ', 'ले', 'प', 'नि', 'सि', 'क्न', 'स', 'क्छ']
#
# Detailed Line-by-Line Analysis:
# Line 1: Pattern=SSISSIISISS, Exact Match='इन्द्रवज्रा', Closest Match='None'
# Line 2: Pattern=SSISSIISISS, Exact Match='इन्द्रवज्रा', Closest Match='None'
#
# Most Suitable Chhanda: इन्द्रवज्रा
# ========================================
#
# Testing Poem: श्री (Expected Chhanda: श्री)
# SS ['आ', 'यो']
# विश्लेषण: 'आ: यो...'
# ------------------------------
#  syllable count (2) Chhandas: None
# SS ['आ', 'यो']
# SS ['के', 'हो']
#
# Detailed Line-by-Line Analysis:
# Line 1: Pattern=SS, Exact Match='None', Closest Match='None'
# Line 2: Pattern=SS, Exact Match='None', Closest Match='None'
#
# Most Suitable Chhanda: None
# ========================================
#
# Testing Poem: स्वागता (Expected Chhanda: स्वागता)
# SISIIISIISS ['अ', 'ङ्ग', 'भ', 'ङ्ग', 'हु', 'न', 'गो', 'ग', 'रि', 'खा', 'ने']
# विश्लेषण: 'अङ्ग-भङ्ग हुन गो गरिखाने...'
# ------------------------------
#  syllable count (11) Chhandas: इन्द्रवज्रा, स्वागता, रथोद्धता, इन्दिरा, उपेन्द्रवज्रा, शालिनी, सत्यवती, अनुकुला
# SISIIISIISS ['अ', 'ङ्ग', 'भ', 'ङ्ग', 'हु', 'न', 'गो', 'ग', 'रि', 'खा', 'ने']
# SISIIISIISS ['छै', 'न', 'चा', 'ह', 'त', 'उ', 'सै', 'म', 'रि', 'जा', 'ने']
#
# Detailed Line-by-Line Analysis:
# Line 1: Pattern=SISIIISIISS, Exact Match='स्वागता', Closest Match='None'
# Line 2: Pattern=SISIIISIISS, Exact Match='स्वागता', Closest Match='None'
#
# Most Suitable Chhanda: स्वागता
# ========================================
#
# Testing Poem: रथोद्धता (Expected Chhanda: रथोद्धता)
# SISIIISISIS ['भो', 'भ', 'यो', 'अ', 'ब', 'य', 'ता', 'न', 'फ', 'र्क', 'नू']
# विश्लेषण: 'भो भयो अब यता नफर्कनू...'
# ------------------------------
#  syllable count (11) Chhandas: इन्द्रवज्रा, स्वागता, रथोद्धता, इन्दिरा, उपेन्द्रवज्रा, शालिनी, सत्यवती, अनुकुला
# SISIIISISIS ['भो', 'भ', 'यो', 'अ', 'ब', 'य', 'ता', 'न', 'फ', 'र्क', 'नू']
# SISIIISISIS ['दु', 'ख्छ', 'घा', 'उ', 'ज', 'ल', 'भै', 'न', 'द', 'र्क', 'नू']
#
# Detailed Line-by-Line Analysis:
# Line 1: Pattern=SISIIISISIS, Exact Match='रथोद्धता', Closest Match='None'
# Line 2: Pattern=SISIIISISIS, Exact Match='रथोद्धता', Closest Match='None'
#
# Most Suitable Chhanda: रथोद्धता
# ========================================
#
# Testing Poem: वियोगिनी (Expected Chhanda: वियोगिनी)
# IISIISISSS ['त', 'न', 'मा', 'कु', 'न', 'त', 'त्व', 'पो', 'प', 'स्यो']
# विश्लेषण: 'तनमा कुन तत्व पो पस्यो ?...'
# ------------------------------
#  syllable count (10) Chhandas: चम्पकमाला, माद्री, रुक्मवती
# IISIISISSS ['त', 'न', 'मा', 'कु', 'न', 'त', 'त्व', 'पो', 'प', 'स्यो']
# IISSIISISSS ['म', 'न', 'मा', 'त्यो', 'कि', 'न', 'गै', 'क', 'ता', 'ब', 'स्यो']
#
# Detailed Line-by-Line Analysis:
# Line 1: Pattern=IISIISISSS, Exact Match='None', Closest Match='चम्पकमाला (diff: 4)'
# Line 2: Pattern=IISSIISISSS, Exact Match='None', Closest Match='उपेन्द्रवज्रा (diff: 2)'
#
# Most Suitable Chhanda: चम्पकमाला
# ========================================
#
# Testing Poem: वसन्त मालिका (Expected Chhanda: वसन्त मालिका)
# IISIISISISS ['श', 'व', 'को', 'कु', 'न', 'हु', 'न्छ', 'का', 'म', 'ना', 'नै']
# विश्लेषण: 'शवको कुन हुन्छ कामना नै ?...'
# ------------------------------
#  syllable count (11) Chhandas: इन्द्रवज्रा, स्वागता, रथोद्धता, इन्दिरा, उपेन्द्रवज्रा, शालिनी, सत्यवती, अनुकुला
# IISIISISISS ['श', 'व', 'को', 'कु', 'न', 'हु', 'न्छ', 'का', 'म', 'ना', 'नै']
# IISSIISISISS ['श', 'व', 'को', 'के', 'छ', 'र', 'भि', 'त्र', 'भा', 'व', 'ना', 'नै']
#
# Detailed Line-by-Line Analysis:
# Line 1: Pattern=IISIISISISS, Exact Match='None', Closest Match='स्वागता (diff: 3)'
# Line 2: Pattern=IISSIISISISS, Exact Match='None', Closest Match='वंशस्थ (diff: 2)'
#
# Most Suitable Chhanda: स्वागता
# ========================================
#
# Testing Poem: इन्दिरा (Expected Chhanda: इन्दिरा)
# IIISISSISIS ['अ', 'ब', 'त', 'मा', 'हु', 'री', 'भु', 'न्भु', 'ना', 'उँ', 'दै']
# विश्लेषण: 'अब त माहुरी भुन्भुनाउँदै...'
# ------------------------------
#  syllable count (11) Chhandas: इन्द्रवज्रा, स्वागता, रथोद्धता, इन्दिरा, उपेन्द्रवज्रा, शालिनी, सत्यवती, अनुकुला
# IIISISSISIS ['अ', 'ब', 'त', 'मा', 'हु', 'री', 'भु', 'न्भु', 'ना', 'उँ', 'दै']
# IIISISSISIS ['ग', 'ति', 'ब', 'ढा', 'उँ', 'दै', 'गु', 'न्गु', 'ना', 'उँ', 'दै']
#
# Detailed Line-by-Line Analysis:
# Line 1: Pattern=IIISISSISIS, Exact Match='इन्दिरा', Closest Match='None'
# Line 2: Pattern=IIISISSISIS, Exact Match='इन्दिरा', Closest Match='None'
#
# Most Suitable Chhanda: इन्दिरा
# ========================================
#
# Testing Poem: रूपामाली (Expected Chhanda: रूपामाली)
# SSSSSSSSS ['हा', 'मी', 'मा', 'ली', 'बा', 'ली', 'ना', 'ली', 'का']
# विश्लेषण: 'हामी माली बालीनालीका...'
# ------------------------------
#  syllable count (9) Chhandas: रूपामाली
# SSSSSSSSS ['हा', 'मी', 'मा', 'ली', 'बा', 'ली', 'ना', 'ली', 'का']
# SSSSSSSSS ['हा', 'मी', 'फा', 'ली', 'मे', 'ची', 'का', 'ली', 'का']
#
# Detailed Line-by-Line Analysis:
# Line 1: Pattern=SSSSSSSSS, Exact Match='रूपामाली', Closest Match='None'
# Line 2: Pattern=SSSSSSSSS, Exact Match='रूपामाली', Closest Match='None'
#
# Most Suitable Chhanda: रूपामाली
# ========================================
#
# Testing Poem: उपेन्द्रवज्रा (Expected Chhanda: उपेन्द्रवज्रा)
# ISISSIISISS ['उ', 'डे', 'र', 'आ', 'का', 'स', 'क', 'हाँ', 'चु', 'मि', 'न्छ']
# विश्लेषण: 'उडेर आकास कहाँ चुमिन्छ...'
# ------------------------------
#  syllable count (11) Chhandas: इन्द्रवज्रा, स्वागता, रथोद्धता, इन्दिरा, उपेन्द्रवज्रा, शालिनी, सत्यवती, अनुकुला
# ISISSIISISS ['उ', 'डे', 'र', 'आ', 'का', 'स', 'क', 'हाँ', 'चु', 'मि', 'न्छ']
# ISISSIISISS ['सु', 'ते', 'र', 'घै', 'टो', 'क', 'स', 'री', 'भ', 'रि', 'न्छ']
#
# Detailed Line-by-Line Analysis:
# Line 1: Pattern=ISISSIISISS, Exact Match='उपेन्द्रवज्रा', Closest Match='None'
# Line 2: Pattern=ISISSIISISS, Exact Match='उपेन्द्रवज्रा', Closest Match='None'
#
# Most Suitable Chhanda: उपेन्द्रवज्रा
# ========================================
#
# Testing Poem: शालिनी (Expected Chhanda: शालिनी)
# SSSSSISSISS ['ला', 'मो', 'या', 'त्रा', 'पा', 'र', 'ग', 'र्दै', 'म', 'आ', 'ए']
# विश्लेषण: 'लामो यात्रा पार गर्दै म आए...'
# ------------------------------
#  syllable count (11) Chhandas: इन्द्रवज्रा, स्वागता, रथोद्धता, इन्दिरा, उपेन्द्रवज्रा, शालिनी, सत्यवती, अनुकुला
# SSSSSISSISS ['ला', 'मो', 'या', 'त्रा', 'पा', 'र', 'ग', 'र्दै', 'म', 'आ', 'ए']
# SSSSSISSISS ['सा', 'मु', 'न्ने', 'मा', 'भै', 'दि', 'दा', 'लौ', 'र', 'मा', 'ए']
#
# Detailed Line-by-Line Analysis:
# Line 1: Pattern=SSSSSISSISS, Exact Match='शालिनी', Closest Match='None'
# Line 2: Pattern=SSSSSISSISS, Exact Match='शालिनी', Closest Match='None'
#
# Most Suitable Chhanda: शालिनी
# ========================================
#
# Testing Poem: मालती (Expected Chhanda: मालती)
# IIIISIISISIS ['न', 'य', 'न', 'क', 'टा', 'क्ष', 'छु', 'रा', 'भ', 'नूँ', 'कि', 'के']
# विश्लेषण: 'नयन कटाक्ष छुरा भनूँ कि के !...'
# ------------------------------
#  syllable count (12) Chhandas: भुजङ्गप्रयात, तोडक, वंशस्थ, जलधरमाला, कुसुमविचित्रा, स्रग्विणी, मालती, द्रुतविलम्बित, प्रमिताक्षरा, इन्द्रवंशा
# IIIISIISISIS ['न', 'य', 'न', 'क', 'टा', 'क्ष', 'छु', 'रा', 'भ', 'नूँ', 'कि', 'के']
# IIIISIISISIS ['छ', 'म', 'छ', 'म', 'ब', 'ज्छ', 'चु', 'रा', 'भ', 'नूँ', 'कि', 'के']
#
# Detailed Line-by-Line Analysis:
# Line 1: Pattern=IIIISIISISIS, Exact Match='मालती', Closest Match='None'
# Line 2: Pattern=IIIISIISISIS, Exact Match='मालती', Closest Match='None'
#
# Most Suitable Chhanda: मालती
# ========================================
#
# Testing Poem: द्रुतविलम्वित (Expected Chhanda: द्रुतविलम्वित)
# IIISIISIISIS ['न', 'य', 'न', 'भि', 'त्र', 'न', 'दी', 'छ', 'स', 'मु', 'द्र', 'छ']
# विश्लेषण: 'नयनभित्र नदी छ समुद्र छ।...'
# ------------------------------
#  syllable count (12) Chhandas: भुजङ्गप्रयात, तोडक, वंशस्थ, जलधरमाला, कुसुमविचित्रा, स्रग्विणी, मालती, द्रुतविलम्बित, प्रमिताक्षरा, इन्द्रवंशा
# IIISIISIISIS ['न', 'य', 'न', 'भि', 'त्र', 'न', 'दी', 'छ', 'स', 'मु', 'द्र', 'छ']
# IIISIISIISIS ['त', 'र', 'मु', 'हा', 'न', 'उ', 'ही', 'छ', 'वि', 'चि', 'त्र', 'छ']
#
# Detailed Line-by-Line Analysis:
# Line 1: Pattern=IIISIISIISIS, Exact Match='द्रुतविलम्बित', Closest Match='None'
# Line 2: Pattern=IIISIISIISIS, Exact Match='द्रुतविलम्बित', Closest Match='None'
#
# Most Suitable Chhanda: द्रुतविलम्बित
# ========================================
#
# Testing Poem: मणिमाला (Expected Chhanda: मणिमाला)
# SIISSSIIS ['खो', 'ल्द', 'छ', 'प', 'र्दा', 'त्यो', 'न', 'य', 'मा']
# विश्लेषण: 'खोल्दछ पर्दा त्यो नयमा...'
# ------------------------------
#  syllable count (9) Chhandas: रूपामाली
# SIISSSIIS ['खो', 'ल्द', 'छ', 'प', 'र्दा', 'त्यो', 'न', 'य', 'मा']
# SIISSSIIS ['ब', 'ल्छ', 'स', 'धैं', 'नै', 'जा', 'ग', 'र', 'मा']
#
# Detailed Line-by-Line Analysis:
# Line 1: Pattern=SIISSSIIS, Exact Match='None', Closest Match='रूपामाली (diff: 4)'
# Line 2: Pattern=SIISSSIIS, Exact Match='None', Closest Match='रूपामाली (diff: 4)'
#
# Most Suitable Chhanda: रूपामाली
# ========================================
#
# Testing Poem: पञ्चचामर (Expected Chhanda: पञ्चचामर)
# ISISISISISISISIS ['ब', 'से', 'र', 'दे', 'श', 'को', 'स', 'धैँ', 'ग', 'रे', 'र', 'ही', 'त', 'खा', 'ति', 'र']
# विश्लेषण: 'बसेर देशको सधैँ गरेर हीत खातिर...'
# ------------------------------
#  syllable count (16) Chhandas: पञ्चचामर, प्रीतिमाला, विधाता, अचलधृति
# ISISISISISISISIS ['ब', 'से', 'र', 'दे', 'श', 'को', 'स', 'धैँ', 'ग', 'रे', 'र', 'ही', 'त', 'खा', 'ति', 'र']
# ISISISISISISISIS ['म', 'रे', 'र', 'ला', 'नु', 'के', 'छ', 'यो', 'अ', 'ज', 'म्ब', 'री', 'त', 'को', 'छ', 'र']
#
# Detailed Line-by-Line Analysis:
# Line 1: Pattern=ISISISISISISISIS, Exact Match='पञ्चचामर', Closest Match='None'
# Line 2: Pattern=ISISISISISISISIS, Exact Match='पञ्चचामर', Closest Match='None'
#
# Most Suitable Chhanda: पञ्चचामर
# ========================================
#
# Testing Poem: अपराजिता (Expected Chhanda: अपराजिता)
# IIIIIISISIISIS ['छ', 'ल', 'र', 'व', 'ल', 'ग', 'री', 'थु', 'नी', 'क', 'न', 'बाँ', 'धि', 'यो']
# विश्लेषण: 'छल र वल गरी थुनीकन बाँधियो...'
# ------------------------------
#  syllable count (14) Chhandas: वसन्ततिलका, अलोला, अपराजिता, दिक्पाल
# IIIIIISISIISIS ['छ', 'ल', 'र', 'व', 'ल', 'ग', 'री', 'थु', 'नी', 'क', 'न', 'बाँ', 'धि', 'यो']
# IIIIIISISIISIS ['ड', 'ङ', 'कि', 'ड', 'ङ', 'पि', 'टी', 'अ', 'चे', 'त', 'ब', 'ना', 'इ', 'यो']
#
# Detailed Line-by-Line Analysis:
# Line 1: Pattern=IIIIIISISIISIS, Exact Match='अपराजिता', Closest Match='None'
# Line 2: Pattern=IIIIIISISIISIS, Exact Match='अपराजिता', Closest Match='None'
#
# Most Suitable Chhanda: अपराजिता
# ========================================
#
# Testing Poem: वसन्ततिलका (Expected Chhanda: वसन्ततिलका)
# SSISISISIISISS ['रा', 'त्री', 'ग', 'यो', 'अ', 'ब', 'प्र', 'भा', 'त', 'भ', 'ए', 'र', 'आ', 'यो']
# विश्लेषण: 'रात्री गयो अब प्रभात भएर आयो...'
# ------------------------------
#  syllable count (14) Chhandas: वसन्ततिलका, अलोला, अपराजिता, दिक्पाल
# SSISISISIISISS ['रा', 'त्री', 'ग', 'यो', 'अ', 'ब', 'प्र', 'भा', 'त', 'भ', 'ए', 'र', 'आ', 'यो']
# SSISISISIISISS ['छा', 'यो', 'स', 'बै', 'ति', 'र', 'प्र', 'भा', 'स', 'वि', 'ता', 'उ', 'दा', 'यो']
#
# Detailed Line-by-Line Analysis:
# Line 1: Pattern=SSISISISIISISS, Exact Match='None', Closest Match='वसन्ततिलका (diff: 1)'
# Line 2: Pattern=SSISISISIISISS, Exact Match='None', Closest Match='वसन्ततिलका (diff: 1)'
#
# Most Suitable Chhanda: वसन्ततिलका
# ========================================
#
# Testing Poem: प्रीतिमाला (Expected Chhanda: प्रीतिमाला)
# SSSISISSIISISISS ['छा', 'ती', 'बे', 'स्स', 'री', 'ज', 'ला', 'ई', 'ज', 'ल', 'ने', 'त्र', 'को', 'स', 'ला', 'ई']
# विश्लेषण: 'छाती बेस्सरी जलाई,जल नेत्रको सलाई...'
# ------------------------------
#  syllable count (16) Chhandas: पञ्चचामर, प्रीतिमाला, विधाता, अचलधृति
# SSSISISSIISISISS ['छा', 'ती', 'बे', 'स्स', 'री', 'ज', 'ला', 'ई', 'ज', 'ल', 'ने', 'त्र', 'को', 'स', 'ला', 'ई']
# SSSISISSIISISISS ['फ्या', 'क्दै', 'पा', 'स', 'मा', 'न', 'आ', 'ई', 'घ', 'र', 'बा', 'ट', 'दृ', 'ष्टि', 'ला', 'ई']
#
# Detailed Line-by-Line Analysis:
# Line 1: Pattern=SSSISISSIISISISS, Exact Match='None', Closest Match='प्रीतिमाला (diff: 1)'
# Line 2: Pattern=SSSISISSIISISISS, Exact Match='None', Closest Match='प्रीतिमाला (diff: 1)'
#
# Most Suitable Chhanda: प्रीतिमाला
# ========================================
#
# Testing Poem: मदिरा (Expected Chhanda: मदिरा)
# SISSIISIISIISIISIISIIS ['ता', 'ल', 'ब', 'न्यो', 'म', 'दि', 'रा', 'र', 'कु', 'वा', 'प', 'नि', 'भो', 'म', 'दि', 'रा', 'भ', 'व', 'सा', 'ग', 'र', 'भो']
# विश्लेषण: 'ताल बन्यो मदिरा र कुवा पनि भो मदिरा भवसागर भो...'
# ------------------------------
#  syllable count (22) Chhandas: मदिरा
# SISSIISIISIISIISIISIIS ['ता', 'ल', 'ब', 'न्यो', 'म', 'दि', 'रा', 'र', 'कु', 'वा', 'प', 'नि', 'भो', 'म', 'दि', 'रा', 'भ', 'व', 'सा', 'ग', 'र', 'भो']
# SIISIISIISIISIISIISIIS ['सृ', 'ष्टि', 'ज', 'ला', 'म', 'य', 'भो', 'म', 'दि', 'रा', 'त', 'ब', 'यो', 'दु', 'नि', 'याँ', 'प', 'नि', 'मा', 'ति', 'दि', 'यो']
#
# Detailed Line-by-Line Analysis:
# Line 1: Pattern=SISSIISIISIISIISIISIIS, Exact Match='None', Closest Match='मदिरा (diff: 1)'
# Line 2: Pattern=SIISIISIISIISIISIISIIS, Exact Match='मदिरा', Closest Match='None'
#
# Most Suitable Chhanda: मदिरा
# ========================================
#
# Testing Poem: मेघविस्फूर्जिता (Expected Chhanda: मेघविस्फूर्जिता)
# ISSSSSIIIIISSISSISS ['लु', 'ला', 'ले', 'सि', 'र्जे', 'का', 'अ', 'नु', 'प', 'म', 'मि', 'ठा', 'ले', 'ख', 'हा', 'वा', 'हुँ', 'दै', 'छन्']
# विश्लेषण: 'लुलाले सिर्जेका अनुपम मिठा, लेख "हावा" हुँदै छन्...'
# ------------------------------
#  syllable count (19) Chhandas: शार्दूलविक्रीडित, मेघविस्फूर्जिता
# ISSSSSIIIIISSISSISS ['लु', 'ला', 'ले', 'सि', 'र्जे', 'का', 'अ', 'नु', 'प', 'म', 'मि', 'ठा', 'ले', 'ख', 'हा', 'वा', 'हुँ', 'दै', 'छन्']
# ISSSSSIIIIISSISSISS ['ब', 'डा', 'ले', 'खो', 'के', 'का', 'अ', 'ति', 'वि', 'र', 'सि', 'ला', 'श', 'ब्द', 'वा', 'वा', 'हुँ', 'दै', 'छन्']
#
# Detailed Line-by-Line Analysis:
# Line 1: Pattern=ISSSSSIIIIISSISSISS, Exact Match='None', Closest Match='मेघविस्फूर्जिता (diff: 1)'
# Line 2: Pattern=ISSSSSIIIIISSISSISS, Exact Match='None', Closest Match='मेघविस्फूर्जिता (diff: 1)'
#
# Most Suitable Chhanda: मेघविस्फूर्जिता
# ========================================
#
# Testing Poem: वंशस्थ (Expected Chhanda: वंशस्थ)
# ISISSIISISIS ['पि', 'या', 'र', 'को', 'व', 'न्ध', 'न', 'पो', 'ख', 'डा', 'भ', 'यो']
# विश्लेषण: 'पियारको वन्धन पो खडाभयो...'
# ------------------------------
#  syllable count (12) Chhandas: भुजङ्गप्रयात, तोडक, वंशस्थ, जलधरमाला, कुसुमविचित्रा, स्रग्विणी, मालती, द्रुतविलम्बित, प्रमिताक्षरा, इन्द्रवंशा
# ISISSIISISIS ['पि', 'या', 'र', 'को', 'व', 'न्ध', 'न', 'पो', 'ख', 'डा', 'भ', 'यो']
# ISISSIISISIS ['य', 'हाँ', 'त', 'गा', 'रो', 'म', 'न', 'को', 'क', 'डा', 'भ', 'यो']
#
# Detailed Line-by-Line Analysis:
# Line 1: Pattern=ISISSIISISIS, Exact Match='वंशस्थ', Closest Match='None'
# Line 2: Pattern=ISISSIISISIS, Exact Match='वंशस्थ', Closest Match='None'
#
# Most Suitable Chhanda: वंशस्थ
# ========================================
#
# Testing Poem: प्रहर्षिणी (Expected Chhanda: प्रहर्षिणी)
# SSSIIIISISISS ['ब', 'च्चा', 'ले', 'क', 'ति', 'थ', 'रि', 'का', 'म', 'जा', 'लिँ', 'दै', 'छन्']
# विश्लेषण: 'बच्चाले कतिथरिका मजा लिँदैछन्...'
# ------------------------------
#  syllable count (13) Chhandas: प्रहर्षिणी, मनिका
# SSSIIIISISISS ['ब', 'च्चा', 'ले', 'क', 'ति', 'थ', 'रि', 'का', 'म', 'जा', 'लिँ', 'दै', 'छन्']
# SSSIIIISISISS ['मा', 'टो', 'मा', 'लु', 'टु', 'पु', 'टिँ', 'दै', 'र', 'मा', 'उँ', 'दै', 'छन्']
#
# Detailed Line-by-Line Analysis:
# Line 1: Pattern=SSSIIIISISISS, Exact Match='प्रहर्षिणी', Closest Match='None'
# Line 2: Pattern=SSSIIIISISISS, Exact Match='प्रहर्षिणी', Closest Match='None'
#
# Most Suitable Chhanda: प्रहर्षिणी
# ========================================
#
# Testing Poem: मात्रिक (Expected Chhanda: मात्रिक)
# IIIISIIIISS ['म', 'प', 'नि', 'रि', 'ले', 'अ', 'न', 'स', 'न', 'मा', 'छु']
# विश्लेषण: 'म पनि रिले अनसनमा छु...'
# ------------------------------
#  syllable count (11) Chhandas: इन्द्रवज्रा, स्वागता, रथोद्धता, इन्दिरा, उपेन्द्रवज्रा, शालिनी, सत्यवती, अनुकुला
# IIIISIIIISS ['म', 'प', 'नि', 'रि', 'ले', 'अ', 'न', 'स', 'न', 'मा', 'छु']
# SSIISIISS ['खा', 'ए', 'प', 'छि', 'हा', 'जि', 'र', 'हु', 'न्छु']
#
# Detailed Line-by-Line Analysis:
# Line 1: Pattern=IIIISIIIISS, Exact Match='None', Closest Match='अनुकुला (diff: 2)'
# Line 2: Pattern=SSIISIISS, Exact Match='None', Closest Match='रूपामाली (diff: 4)'
#
# Most Suitable Chhanda: अनुकुला
# ========================================
#
# Testing Poem: अार्या (Expected Chhanda: अार्या)
# SIISSSIIIISSISSISSIS ['ध', 'न्य', 'छ', 'ना', 'री', 'जी', 'व', 'न', 'क', 'स', 'ले', 'बु', 'झ्न', 'स', 'क्ला', 'र', 'ति', 'म्रो', 'म', 'न']
# विश्लेषण: 'धन्य छ नारी जीवन, कसले बुझ्न सक्ला र तिम्रो मन...'
# ------------------------------
#  syllable count (20) Chhandas: None
# SIISSSIIIISSISSISSIS ['ध', 'न्य', 'छ', 'ना', 'री', 'जी', 'व', 'न', 'क', 'स', 'ले', 'बु', 'झ्न', 'स', 'क्ला', 'र', 'ति', 'म्रो', 'म', 'न']
# SISISSIIIIIISIISISISS ['भि', 'त्र', 'वे', 'द', 'ना', 'द', 'न्द', 'न', 'त', 'र', 'प', 'नि', 'बा', 'हि', 'र', 'मु', 'स्कु', 'रा', 'उँ', 'दै', 'छन्']
#
# Detailed Line-by-Line Analysis:
# Line 1: Pattern=SIISSSIIIISSISSISSIS, Exact Match='None', Closest Match='None'
# Line 2: Pattern=SISISSIIIIIISIISISISS, Exact Match='None', Closest Match='स्रग्धरा (diff: 4)'
#
# Most Suitable Chhanda: None
# ========================================
#
# Testing Poem: प्रमिताक्षरा (Expected Chhanda: प्रमिताक्षरा)
# IISSSIIISIIS ['त', 'र', 'या', 'र', 'प्या', 'र', 'न', 'ग', 'री', 'न', 'हु', 'ने']
# विश्लेषण: 'तर यार प्यार नगरी नहुने...'
# ------------------------------
#  syllable count (12) Chhandas: भुजङ्गप्रयात, तोडक, वंशस्थ, जलधरमाला, कुसुमविचित्रा, स्रग्विणी, मालती, द्रुतविलम्बित, प्रमिताक्षरा, इन्द्रवंशा
# IISSSIIISIIS ['त', 'र', 'या', 'र', 'प्या', 'र', 'न', 'ग', 'री', 'न', 'हु', 'ने']
# IISISIIISIIS ['उ', 'न', 'को', 'स', 'मी', 'प', 'न', 'स', 'री', 'न', 'हु', 'ने']
#
# Detailed Line-by-Line Analysis:
# Line 1: Pattern=IISSSIIISIIS, Exact Match='None', Closest Match='प्रमिताक्षरा (diff: 1)'
# Line 2: Pattern=IISISIIISIIS, Exact Match='प्रमिताक्षरा', Closest Match='None'
#
# Most Suitable Chhanda: प्रमिताक्षरा
# ========================================
#
# Testing Poem: तोडक (Expected Chhanda: तोडक)
# IISIISIISIIS ['अ', 'ब', 'ता', 'अ', 'ति', 'भाे', 'अ', 'ति', 'नै', 'ख', 'ति', 'भो']
# विश्लेषण: 'अबता अति भाे,अति नै खति भो।...'
# ------------------------------
#  syllable count (12) Chhandas: भुजङ्गप्रयात, तोडक, वंशस्थ, जलधरमाला, कुसुमविचित्रा, स्रग्विणी, मालती, द्रुतविलम्बित, प्रमिताक्षरा, इन्द्रवंशा
# IISIISIISIIS ['अ', 'ब', 'ता', 'अ', 'ति', 'भाे', 'अ', 'ति', 'नै', 'ख', 'ति', 'भो']
# IISIISISSIIS ['स', 'ब', 'को', 'म', 'ति', 'लौ', 'अ', 'ति', 'भ्र', 'ष्ट', 'भ', 'याे']
#
# Detailed Line-by-Line Analysis:
# Line 1: Pattern=IISIISIISIIS, Exact Match='तोडक', Closest Match='None'
# Line 2: Pattern=IISIISISSIIS, Exact Match='None', Closest Match='तोडक (diff: 1)'
#
# Most Suitable Chhanda: तोडक
# ========================================
#
# Testing Poem: पृथ्वी (Expected Chhanda: पृथ्वी)
# ISIIISISIIISISSIS ['अ', 'च', 'म्म', 'अ', 'ति', 'ला', 'ग्छ', 'है', 'कि', 'न', 'श', 'री', 'र', 'का', 'अ', 'ङ्ग', 'मा']
# विश्लेषण: 'अचम्म अति लाग्छ है किन शरीरका अङ्गमा...'
# ------------------------------
#  syllable count (17) Chhandas: शिखरिणी, मन्दाक्रान्ता, पृथ्वी, हरिणी
# ISIIISISIIISISSIS ['अ', 'च', 'म्म', 'अ', 'ति', 'ला', 'ग्छ', 'है', 'कि', 'न', 'श', 'री', 'र', 'का', 'अ', 'ङ्ग', 'मा']
# ISIIISISIIISISSIS ['वि', 'भे', 'द', 'न', 'हु', 'ने', 'क', 'ठै', 'अ', 'ध', 'र', 'वा', 'क', 'नि', 'ष्ठा', 'ङ्ग', 'मा']
#
# Detailed Line-by-Line Analysis:
# Line 1: Pattern=ISIIISISIIISISSIS, Exact Match='पृथ्वी', Closest Match='None'
# Line 2: Pattern=ISIIISISIIISISSIS, Exact Match='पृथ्वी', Closest Match='None'
#
# Most Suitable Chhanda: पृथ्वी
# ========================================
#
# Testing Poem: दुर्मिला (Expected Chhanda: दुर्मिला)
# IISIISIISIISIISIISIISIIS ['ज', 'ब', 'यो', 'यु', 'ग', 'नै', 'अ', 'ल', 'म', 'ल्ल', 'भ', 'यो', 'त', 'ब', 'यो', 'ज', 'ग', 'नै', 'ख', 'ल', 'ब', 'ल्ल', 'भ', 'यो']
# विश्लेषण: 'जब यो युग नै अलमल्ल भयो, तब यो जग नै खलबल्ल भयो...'
# ------------------------------
#  syllable count (24) Chhandas: दुर्मिला
# IISIISIISIISIISIISIISIIS ['ज', 'ब', 'यो', 'यु', 'ग', 'नै', 'अ', 'ल', 'म', 'ल्ल', 'भ', 'यो', 'त', 'ब', 'यो', 'ज', 'ग', 'नै', 'ख', 'ल', 'ब', 'ल्ल', 'भ', 'यो']
# IISIISIISIISIISIISIISIIS ['र', 'स', 'चु', 'स्छ', 'स', 'धैं', 'भ', 'म', 'रो', 'र', 'जु', 'को', 'अ', 'नि', 'फू', 'ल', 'सु', 'की', 'अ', 'स', 'र', 'ल्ल', 'भ', 'यो']
#
# Detailed Line-by-Line Analysis:
# Line 1: Pattern=IISIISIISIISIISIISIISIIS, Exact Match='दुर्मिला', Closest Match='None'
# Line 2: Pattern=IISIISIISIISIISIISIISIIS, Exact Match='दुर्मिला', Closest Match='None'
#
# Most Suitable Chhanda: दुर्मिला
# ========================================
#
# Testing Poem: स्रग्धरा (Expected Chhanda: स्रग्धरा)
# SSSSISSIIIIIISSISSISSS ['पा', 'खा', 'मा', 'खे', 'त', 'मा', 'यी', 'ल', 'ह', 'ल', 'ह', 'ग', 'हुँ', 'का', 'पु', 'ष्ट', 'बा', 'ली', 'झु', 'ला', 'र्', 'इ']
# विश्लेषण: 'पाखामा खेतमा यी लहलह गहुँका पुष्ट बाली झुलार्इ...'
# ------------------------------
#  syllable count (22) Chhandas: मदिरा
# SSSSISSIIIIIISSISSISSS ['पा', 'खा', 'मा', 'खे', 'त', 'मा', 'यी', 'ल', 'ह', 'ल', 'ह', 'ग', 'हुँ', 'का', 'पु', 'ष्ट', 'बा', 'ली', 'झु', 'ला', 'र्', 'इ']
# SSSSISSSIIIIIISSISSISSS ['मा', 'न्छे', 'को', 'चे', 'त', 'ला', 'र्', 'इ', 'प्र', 'कृ', 'ति', 'ल', 'य', 'सँ', 'गै', 'दू', 'र', 'ता', 'न्दै', 'डु', 'ला', 'र्', 'इ']
#
# Detailed Line-by-Line Analysis:
# Line 1: Pattern=SSSSISSIIIIIISSISSISSS, Exact Match='None', Closest Match='मदिरा (diff: 9)'
# Line 2: Pattern=SSSSISSSIIIIIISSISSISSS, Exact Match='None', Closest Match='None'
#
# Most Suitable Chhanda: मदिरा
# ========================================
#
# Testing Poem: विधाता (Expected Chhanda: विधाता)
# ISSSISSSISSSISSS ['उ', 'नी', 'रा', 'नी', 'म', 'ता', 'रा', 'जा', 'ब', 'ने', 'को', 'त्यो', 'कु', 'रा', 'आ', 'यो']
# विश्लेषण: 'उनी रानी म ता राजा बनेको त्यो कुरा आयो...'
# ------------------------------
#  syllable count (16) Chhandas: पञ्चचामर, प्रीतिमाला, विधाता, अचलधृति
# ISSSISSSISSSISSS ['उ', 'नी', 'रा', 'नी', 'म', 'ता', 'रा', 'जा', 'ब', 'ने', 'को', 'त्यो', 'कु', 'रा', 'आ', 'यो']
# ISSSISSSISSSISSS ['स', 'गै', 'बा', 'चौ', 'म', 'रौ', 'हा', 'मी', 'भ', 'ने', 'को', 'त्यो', 'कु', 'रा', 'आ', 'यो']
#
# Detailed Line-by-Line Analysis:
# Line 1: Pattern=ISSSISSSISSSISSS, Exact Match='विधाता', Closest Match='None'
# Line 2: Pattern=ISSSISSSISSSISSS, Exact Match='विधाता', Closest Match='None'
#
# Most Suitable Chhanda: विधाता
# ========================================
#
# Testing Poem: मनिका (Expected Chhanda: मनिका)
# IISISSISSSISS ['ग', 'ण', 'त', 'न्त्र', 'आ', 'यो', 'अ', 'रू', 'के', 'पो', 'पु', 'गे', 'न']
# विश्लेषण: 'गणतन्त्र आयो अरू, के पो पुगेन?...'
# ------------------------------
#  syllable count (13) Chhandas: प्रहर्षिणी, मनिका
# IISISSISSSISS ['ग', 'ण', 'त', 'न्त्र', 'आ', 'यो', 'अ', 'रू', 'के', 'पो', 'पु', 'गे', 'न']
# IISISSISSSISS ['र', 'श', 'ही', 'द', 'का', 'र', 'क्त', 'का', 'टा', 'टा', 'सु', 'के', 'न']
#
# Detailed Line-by-Line Analysis:
# Line 1: Pattern=IISISSISSSISS, Exact Match='मनिका', Closest Match='None'
# Line 2: Pattern=IISISSISSSISS, Exact Match='मनिका', Closest Match='None'
#
# Most Suitable Chhanda: मनिका
# ========================================
#
# Testing Poem: हरिणी (Expected Chhanda: हरिणी)
# IIIIISSSSSISIISIS ['कु', 'सु', 'म', 'द', 'ल', 'फ', 'क्रे', 'को', 'उ', 'द्या', 'न', 'मा', 'कि', 'न', 'हो', 'भ', 'न']
# विश्लेषण: 'कुसुमदल ! फक्रेको उद्यानमा किन हो भन ?...'
# ------------------------------
#  syllable count (17) Chhandas: शिखरिणी, मन्दाक्रान्ता, पृथ्वी, हरिणी
# IIIIISSSSSISIISIS ['कु', 'सु', 'म', 'द', 'ल', 'फ', 'क्रे', 'को', 'उ', 'द्या', 'न', 'मा', 'कि', 'न', 'हो', 'भ', 'न']
# IIIIISSSSSISIISIS ['भ्र', 'म', 'र', 'कु', 'ल', 'झु', 'ल्दै', 'छ', 'न्मा', 'धु', 'र्य', 'को', 'क', 'वि', 'ता', 'लि', 'न']
#
# Detailed Line-by-Line Analysis:
# Line 1: Pattern=IIIIISSSSSISIISIS, Exact Match='हरिणी', Closest Match='None'
# Line 2: Pattern=IIIIISSSSSISIISIS, Exact Match='हरिणी', Closest Match='None'
#
# Most Suitable Chhanda: हरिणी
# ========================================
#
# Testing Poem: दिक्पाल (Expected Chhanda: दिक्पाल)
# SSISISSSSISISS ['था', 'मे', 'र', 'हा', 'त', 'ति', 'म्रो', 'बाँ', 'चे', 'म', 'आ', 'ज', 'स', 'म्म']
# विश्लेषण: 'थामेर हात तिम्रो,बाँचे म आज सम्म...'
# ------------------------------
#  syllable count (14) Chhandas: वसन्ततिलका, अलोला, अपराजिता, दिक्पाल
# SSISISSSSISISS ['था', 'मे', 'र', 'हा', 'त', 'ति', 'म्रो', 'बाँ', 'चे', 'म', 'आ', 'ज', 'स', 'म्म']
# SSISISSSSISISS ['पा', 'ए', 'र', 'सा', 'थ', 'ति', 'म्रो', 'बाँ', 'चे', 'म', 'आ', 'ज', 'स', 'म्म']
#
# Detailed Line-by-Line Analysis:
# Line 1: Pattern=SSISISSSSISISS, Exact Match='दिक्पाल', Closest Match='None'
# Line 2: Pattern=SSISISSSSISISS, Exact Match='दिक्पाल', Closest Match='None'
#
# Most Suitable Chhanda: दिक्पाल
# ========================================
#
# Testing Poem: चित्रपदा (Expected Chhanda: चित्रपदा)
# SIISIISSSIISIISS ['जा', 'न', 'ज', 'ता', 'ति', 'र', 'जा', 'ऊ', 'यै', 'घ', 'र', 'मा', 'म', 'न', 'ला', 'ऊ']
# विश्लेषण: 'जान जतातिर जाऊ, यै घरमा मन लाऊ...'
# ------------------------------
#  syllable count (16) Chhandas: पञ्चचामर, प्रीतिमाला, विधाता, अचलधृति
# SIISIISSSIISIISS ['जा', 'न', 'ज', 'ता', 'ति', 'र', 'जा', 'ऊ', 'यै', 'घ', 'र', 'मा', 'म', 'न', 'ला', 'ऊ']
# SIISIISSSIISIISS ['दे', 'श', 'रु', 'ने', 'न', 'ग', 'रा', 'ऊ', 'जो', 'स', 'कि', 'ने', 'श्र', 'म', 'ला', 'ऊ']
#
# Detailed Line-by-Line Analysis:
# Line 1: Pattern=SIISIISSSIISIISS, Exact Match='None', Closest Match='प्रीतिमाला (diff: 6)'
# Line 2: Pattern=SIISIISSSIISIISS, Exact Match='None', Closest Match='प्रीतिमाला (diff: 6)'
#
# Most Suitable Chhanda: प्रीतिमाला
# ========================================
#
# Testing Poem: पुष्पिताग्रा (Expected Chhanda: पुष्पिताग्रा)
# IIIIIISISISS ['ज', 'न', 'न', 'हु', 'न', 'स', 'मे', 'त', 'बा', 'बु', 'खो', 'ज्ने']
# विश्लेषण: 'जनन हुन समेत बाबु खोज्ने...'
# ------------------------------
#  syllable count (12) Chhandas: भुजङ्गप्रयात, तोडक, वंशस्थ, जलधरमाला, कुसुमविचित्रा, स्रग्विणी, मालती, द्रुतविलम्बित, प्रमिताक्षरा, इन्द्रवंशा
# IIIIIISISISS ['ज', 'न', 'न', 'हु', 'न', 'स', 'मे', 'त', 'बा', 'बु', 'खो', 'ज्ने']
# IIIISIISISISS ['ज', 'न', 'न', 'भ', 'ए', 'उ', 'स', 'कै', 'छ', 'वं', 'श', 'ब', 'ढ्ने']
#
# Detailed Line-by-Line Analysis:
# Line 1: Pattern=IIIIIISISISS, Exact Match='None', Closest Match='मालती (diff: 2)'
# Line 2: Pattern=IIIISIISISISS, Exact Match='None', Closest Match='मनिका (diff: 3)'
#
# Most Suitable Chhanda: मालती
# ========================================
#
# Testing Poem: माद्री (Expected Chhanda: माद्री)
# ISISSIISIS ['म', 'वे', 'द', 'ना', 'मा', 'क', 'स', 'री', 'ब', 'सौँ']
# विश्लेषण: 'म वेदनामा कसरी बसौँ...'
# ------------------------------
#  syllable count (10) Chhandas: चम्पकमाला, माद्री, रुक्मवती
# ISISSIISIS ['म', 'वे', 'द', 'ना', 'मा', 'क', 'स', 'री', 'ब', 'सौँ']
# ISISSIISIS ['प्र', 'ता', 'ड', 'ना', 'मा', 'क', 'स', 'री', 'ब', 'सौँ']
#
# Detailed Line-by-Line Analysis:
# Line 1: Pattern=ISISSIISIS, Exact Match='माद्री', Closest Match='None'
# Line 2: Pattern=ISISSIISIS, Exact Match='माद्री', Closest Match='None'
#
# Most Suitable Chhanda: माद्री
# ========================================
#
# Testing Poem: सुप्रतिष्ठा (Expected Chhanda: सुप्रतिष्ठा)
# SIISS ['हे', 'र', 'बि', 'रा', 'ला']
# विश्लेषण: 'हेर बिराला...'
# ------------------------------
#  syllable count (5) Chhandas: सुप्रतिष्ठा
# SIISS ['हे', 'र', 'बि', 'रा', 'ला']
# SIISS ['धू', 'र्त', 'छ', 'चा', 'ला']
#
# Detailed Line-by-Line Analysis:
# Line 1: Pattern=SIISS, Exact Match='सुप्रतिष्ठा', Closest Match='None'
# Line 2: Pattern=SIISS, Exact Match='सुप्रतिष्ठा', Closest Match='None'
#
# Most Suitable Chhanda: सुप्रतिष्ठा
# ========================================
#
# Testing Poem: तूर्णक (Expected Chhanda: तूर्णक)
# SISISISISISISSS ['हो', 'स', 'रा', 'ख', 'दो', 'ष', 'छो', 'ड', 'क', 'र्म', 'ग', 'र्न', 'त', 'म्सि', 'द्यौ']
# विश्लेषण: 'होस राख, दोष छोड, कर्म गर्न तम्सिद्यौ...'
# ------------------------------
#  syllable count (15) Chhandas: मालिनी, तूर्णक, चित्रिका
# SISISISISISISSS ['हो', 'स', 'रा', 'ख', 'दो', 'ष', 'छो', 'ड', 'क', 'र्म', 'ग', 'र्न', 'त', 'म्सि', 'द्यौ']
# SISISISISISISSS ['नि', 'ष्क', 'ल', 'ङ्क', 'क', 'र्म', 'बा', 'ट', 'ब', 'न्छ', 'दे', 'श', 'सं', 'झि', 'द्यौ']
#
# Detailed Line-by-Line Analysis:
# Line 1: Pattern=SISISISISISISSS, Exact Match='None', Closest Match='तूर्णक (diff: 1)'
# Line 2: Pattern=SISISISISISISSS, Exact Match='None', Closest Match='तूर्णक (diff: 1)'
#
# Most Suitable Chhanda: तूर्णक
# ========================================
#
# Testing Poem: सत्यवती (Expected Chhanda: सत्यवती)
# SIISSISISS ['आ', 'खि', 'र', 'छो', 'टो', 'छ', 'जि', 'न्द', 'गा', 'नी']
# विश्लेषण: 'आखिर छोटो छ जिन्दगानी...'
# ------------------------------
#  syllable count (10) Chhandas: चम्पकमाला, माद्री, रुक्मवती
# SIISSISISS ['आ', 'खि', 'र', 'छो', 'टो', 'छ', 'जि', 'न्द', 'गा', 'नी']
# SIISSISISS ['ब', 'न्नु', 'छ', 'हा', 'मी', 'स', 'बै', 'ख', 'रा', 'नी']
#
# Detailed Line-by-Line Analysis:
# Line 1: Pattern=SIISSISISS, Exact Match='None', Closest Match='चम्पकमाला (diff: 2)'
# Line 2: Pattern=SIISSISISS, Exact Match='None', Closest Match='चम्पकमाला (diff: 2)'
#
# Most Suitable Chhanda: चम्पकमाला
# ========================================
#
# Testing Poem: चित्रा (Expected Chhanda: चित्रा)
# SSSSSSSSSISSISS ['द्यौ', 'रा', 'ली', 'मा', 'पा', 'ती', 'मे', 'राे', 'ना', 'म', 'अ', 'र्काे', 'प', 'रे', 'छ']
# विश्लेषण: 'द्यौरालीमा पाती मेराे नाम अर्काे परेछ...'
# ------------------------------
#  syllable count (15) Chhandas: मालिनी, तूर्णक, चित्रिका
# SSSSSSSSSISSISS ['द्यौ', 'रा', 'ली', 'मा', 'पा', 'ती', 'मे', 'राे', 'ना', 'म', 'अ', 'र्काे', 'प', 'रे', 'छ']
# SSSSSSSSSISSISS ['सा', 'नो', 'छा', 'या', 'प्या', 'राे', 'ला', 'ग्थ्यो', 'घा', 'म', 'च', 'र्काे', 'प', 'रे', 'छ']
#
# Detailed Line-by-Line Analysis:
# Line 1: Pattern=SSSSSSSSSISSISS, Exact Match='None', Closest Match='मालिनी (diff: 6)'
# Line 2: Pattern=SSSSSSSSSISSISS, Exact Match='None', Closest Match='मालिनी (diff: 6)'
#
# Most Suitable Chhanda: मालिनी
# ========================================
#
# Testing Poem: चित्रिका (Expected Chhanda: चित्रिका)
# SISISISISISISIS ['जा', 'ग', 'जा', 'ग', 'हे', 'यु', 'वा', 'उ', 'दा', 'र', 'शा', 'न्त', 'चि', 'त्त', 'ले']
# विश्लेषण: 'जाग जाग हे युवा उदार शान्त चित्तले...'
# ------------------------------
#  syllable count (15) Chhandas: मालिनी, तूर्णक, चित्रिका
# SISISISISISISIS ['जा', 'ग', 'जा', 'ग', 'हे', 'यु', 'वा', 'उ', 'दा', 'र', 'शा', 'न्त', 'चि', 'त्त', 'ले']
# SISISISISISISIS ['हाँ', 'क्नु', 'प', 'र्छ', 'दे', 'श', 'यो', 'सु', 'र', 'म्य', 'नी', 'ति', 'वि', 'त्त', 'ले']
#
# Detailed Line-by-Line Analysis:
# Line 1: Pattern=SISISISISISISIS, Exact Match='तूर्णक', Closest Match='None'
# Line 2: Pattern=SISISISISISISIS, Exact Match='तूर्णक', Closest Match='None'
#
# Most Suitable Chhanda: तूर्णक
# ========================================
#
# Testing Poem: इन्द्रवंशा (Expected Chhanda: इन्द्रवंशा)
# SSISSIISISIS ['को', 'हु', 'न्कु', 'दे', 'का', 'कि', 'न', 'जा', 'ल', 'झे', 'ल', 'मा']
# विश्लेषण: 'को हुन् कुदेका किन जालझेलमा...'
# ------------------------------
#  syllable count (12) Chhandas: भुजङ्गप्रयात, तोडक, वंशस्थ, जलधरमाला, कुसुमविचित्रा, स्रग्विणी, मालती, द्रुतविलम्बित, प्रमिताक्षरा, इन्द्रवंशा
# SSISSIISISIS ['को', 'हु', 'न्कु', 'दे', 'का', 'कि', 'न', 'जा', 'ल', 'झे', 'ल', 'मा']
# SSISSIISISIS ['को', 'हु', 'न्डु', 'बे', 'का', 'कि', 'न', 'र', 'क्त', 'भे', 'ल', 'मा']
#
# Detailed Line-by-Line Analysis:
# Line 1: Pattern=SSISSIISISIS, Exact Match='इन्द्रवंशा', Closest Match='None'
# Line 2: Pattern=SSISSIISISIS, Exact Match='इन्द्रवंशा', Closest Match='None'
#
# Most Suitable Chhanda: इन्द्रवंशा
# ========================================
#
# Testing Poem: रुक्मवती (Expected Chhanda: रुक्मवती)
# SIISSSIISS ['भा', 'व', 'वि', 'ना', 'को', 'ब', 'न्द', 'छ', 'ना', 'रा']
# विश्लेषण: 'भाव विनाको बन्दछ नारा।...'
# ------------------------------
#  syllable count (10) Chhandas: चम्पकमाला, माद्री, रुक्मवती
# SIISSSIISS ['भा', 'व', 'वि', 'ना', 'को', 'ब', 'न्द', 'छ', 'ना', 'रा']
# SIISSSIISS ['जू', 'न', 'फु', 'ला', 'ऊ', 'व्यो', 'म', 'सि', 'ता', 'रा']
#
# Detailed Line-by-Line Analysis:
# Line 1: Pattern=SIISSSIISS, Exact Match='चम्पकमाला', Closest Match='None'
# Line 2: Pattern=SIISSSIISS, Exact Match='चम्पकमाला', Closest Match='None'
#
# Most Suitable Chhanda: चम्पकमाला
# ========================================
#
# Testing Poem: चन्द्रलेखा (Expected Chhanda: चन्द्रलेखा)
# SSSSISSSSISSISS ['आ', 'जै', 'ए', 'का', 'द', 'शी', 'मा', 'छा', 'ता', 'न', 'खा', 'ऊँ', 'तु', 'ला', 'सी']
# विश्लेषण: 'आजै एकादशी माछा ता नखाऊँ तुलासी।...'
# ------------------------------
#  syllable count (15) Chhandas: मालिनी, तूर्णक, चित्रिका
# SSSSISSSSISSISS ['आ', 'जै', 'ए', 'का', 'द', 'शी', 'मा', 'छा', 'ता', 'न', 'खा', 'ऊँ', 'तु', 'ला', 'सी']
# SSSSISSSSISSISS ['अ', 'र्पौं', 'श्री', 'वि', 'ष्णु', 'मा', 'मा', 'ला', 'तो', 'र', 'णै', 'फू', 'ल', 'गाँ', 'सी']
#
# Detailed Line-by-Line Analysis:
# Line 1: Pattern=SSSSISSSSISSISS, Exact Match='None', Closest Match='मालिनी (diff: 5)'
# Line 2: Pattern=SSSSISSSSISSISS, Exact Match='None', Closest Match='मालिनी (diff: 5)'
#
# Most Suitable Chhanda: मालिनी
# ========================================
#
# Testing Poem: शङ्खनारी (Expected Chhanda: शङ्खनारी)
# ISSISS ['क', 'था', 'जि', 'न्द', 'गी', 'को']
# विश्लेषण: 'कथा जिन्दगीको...'
# ------------------------------
#  syllable count (6) Chhandas: विद्युल्लेखा, शङ्खनारी
# ISSISS ['क', 'था', 'जि', 'न्द', 'गी', 'को']
# ISSISS ['थि', 'एॅ', 'ने', 'त्र', 'ना', 'नी']
#
# Detailed Line-by-Line Analysis:
# Line 1: Pattern=ISSISS, Exact Match='शङ्खनारी', Closest Match='None'
# Line 2: Pattern=ISSISS, Exact Match='शङ्खनारी', Closest Match='None'
#
# Most Suitable Chhanda: शङ्खनारी
# ========================================
#
# Testing Poem: अचलधृति (Expected Chhanda: अचलधृति)
# IIIIIIIIIIIIIIIS ['अ', 'वि', 'र', 'ल', 'च', 'र', 'ण', 'र', 'ज', 'अ', 'भि', 'ल', 'षि', 'त', 'म', 'छु']
# विश्लेषण: 'अविरल चरण-रज अभिलषित म छु...'
# ------------------------------
#  syllable count (16) Chhandas: पञ्चचामर, प्रीतिमाला, विधाता, अचलधृति
# IIIIIIIIIIIIIIIS ['अ', 'वि', 'र', 'ल', 'च', 'र', 'ण', 'र', 'ज', 'अ', 'भि', 'ल', 'षि', 'त', 'म', 'छु']
# IIIIIIIIIIIIIIIS ['द्र', 'वि', 'त', 'छ', 'हृ', 'द', 'य', 'त', 'र', 'अ', 'वि', 'च', 'लि', 'त', 'म', 'छु']
#
# Detailed Line-by-Line Analysis:
# Line 1: Pattern=IIIIIIIIIIIIIIIS, Exact Match='None', Closest Match='अचलधृति (diff: 1)'
# Line 2: Pattern=IIIIIIIIIIIIIIIS, Exact Match='None', Closest Match='अचलधृति (diff: 1)'
#
# Most Suitable Chhanda: अचलधृति
# ========================================
#
# Testing Poem: अनुकुला (Expected Chhanda: अनुकुला)
# SIISSSIIIISS ['हे', 'र', 'य', 'हाँ', 'छ', 'न्', 'अ', 'ति', 'श', 'य', 'पी', 'डा']
# विश्लेषण: 'हेर यहाँ छन् अतिशय पीडा...'
# ------------------------------
#  syllable count (12) Chhandas: भुजङ्गप्रयात, तोडक, वंशस्थ, जलधरमाला, कुसुमविचित्रा, स्रग्विणी, मालती, द्रुतविलम्बित, प्रमिताक्षरा, इन्द्रवंशा
# SIISSSIIIISS ['हे', 'र', 'य', 'हाँ', 'छ', 'न्', 'अ', 'ति', 'श', 'य', 'पी', 'डा']
# SIISSIIIISS ['ख', 'प्द', 'छु', 'ज', 'म्मै', 'ह', 'र', 'द', 'म', 'हाँ', 'सी']
#
# Detailed Line-by-Line Analysis:
# Line 1: Pattern=SIISSSIIIISS, Exact Match='None', Closest Match='कुसुमविचित्रा (diff: 2)'
# Line 2: Pattern=SIISSIIIISS, Exact Match='अनुकुला', Closest Match='None'
#
# Most Suitable Chhanda: कुसुमविचित्रा
# ========================================
#
# Testing Poem: मात्रिक (चौपाइ) (Expected Chhanda: मात्रिक (चौपाइ))
# SIIIISIIIISS ['सू', 'र्य', 'कि', 'र', 'ण', 'ले', 'ति', 'मि', 'र', 'ह', 'रा', 'यो']
# विश्लेषण: 'सूर्य किरणले तिमिर हरायो...'
# ------------------------------
#  syllable count (12) Chhandas: भुजङ्गप्रयात, तोडक, वंशस्थ, जलधरमाला, कुसुमविचित्रा, स्रग्विणी, मालती, द्रुतविलम्बित, प्रमिताक्षरा, इन्द्रवंशा
# SIIIISIIIISS ['सू', 'र्य', 'कि', 'र', 'ण', 'ले', 'ति', 'मि', 'र', 'ह', 'रा', 'यो']
# IISSIIIIIISS ['दु', 'नि', 'याँ', 'उ', 'ज्ज्व', 'ल', 'म', 'धु', 'र', 'ग', 'रा', 'यो']
#
# Detailed Line-by-Line Analysis:
# Line 1: Pattern=SIIIISIIIISS, Exact Match='None', Closest Match='कुसुमविचित्रा (diff: 2)'
# Line 2: Pattern=IISSIIIIIISS, Exact Match='None', Closest Match='प्रमिताक्षरा (diff: 3)'
#
# Most Suitable Chhanda: कुसुमविचित्रा
# ========================================
#
# Testing Poem: मालिनी (Expected Chhanda: मालिनी)
# IIIIIISSSISSISS ['क', 'ति', 'छ', 'क', 'ति', 'गु', 'ना', 'सो', 'दे', 'श', 'नै', 'भो', 'वि', 'रा', 'नो']
# विश्लेषण: 'कति छ कति गुनासो देश नै भो विरानो...'
# ------------------------------
#  syllable count (15) Chhandas: मालिनी, तूर्णक, चित्रिका
# IIIIIISSSISSISS ['क', 'ति', 'छ', 'क', 'ति', 'गु', 'ना', 'सो', 'दे', 'श', 'नै', 'भो', 'वि', 'रा', 'नो']
# IIIIIISSSISSSSS ['घ', 'र', 'श', 'ह', 'र', 'स', 'बै', 'को', 'आँ', 'ग', 'नी', 'भो', 'अँ', 'ध्या', 'रो']
#
# Detailed Line-by-Line Analysis:
# Line 1: Pattern=IIIIIISSSISSISS, Exact Match='मालिनी', Closest Match='None'
# Line 2: Pattern=IIIIIISSSISSSSS, Exact Match='None', Closest Match='मालिनी (diff: 1)'
#
# Most Suitable Chhanda: मालिनी
# ========================================
